# %%
from bs4 import BeautifulSoup
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# finding the url

# %%
url = "https://www.top-charts.com/songs"

# %% [markdown]
# Download html with a get request

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %% [markdown]
# Parse html

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, minimal-ui, initial-scale=1, maximum-scale=5" name="viewport"/>
#   <meta content="Chart of the Top 100 songs of the day. List of the most popular songs around the world today." name="description"/>
#   <meta content="https://www.top-charts.com/songs" property="al:web:url"/>
#   <meta content="Top 100 Songs" property="og:title"/>
#   <meta content="https://www.top-charts.com/songs" property="og:url"/>
#   <meta content="Chart of the Top 100 songs of the day. List of the most popular songs around the world today." property="og:description"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Top 100 Songs" name="twitter:title"/>
#   <meta content="https://www.top-charts.com/songs" name="twitter:url"/>
#   <meta content="Chart of the Top 100 songs of the day. List of the most popular songs around the world today." name="twitter:description"/>
#   <meta content="" name="theme-color"/>
#   <link href="https://www.top-charts.com/songs" rel="canonical"/>
#   <title>
#    Top 100 Songs Chart | Top Charts
#   </title>
#   <link href="https://cdn.top-charts.com/static/images/fav.png" rel="shortcut icon" type="image/png"/>
#   <link href="https://www.google-analytics.com/" rel="preconnect"/>
#   <link href="https://cdn.top-charts.com/" rel="preconnect"/>
#   <link href="//www.googletagservices.com" rel="dns-prefetch"/>
#   <link href="https://www.google.com" rel="dns-prefetch"/>
#   <link href="http://www.google.com" rel="dns-prefetch"/>
#   <link href="https://tpc.googlesyndication.com" rel="dns-prefetch"/>
#   <link href="https://fonts.googleapis.com" rel="dns-prefetch"/>
#   <link href="https://fonts.gstatic.com" rel="dns-prefetch"/>
#   <link href="https://ajax.googleapis.com" rel="dns-prefetch"/>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-41201130-43">
#   </script>
#   <script>
#    window.dataLayer=window.dataLayer||[];function gtag(){dataLayer.push(arguments);}
# gtag('js',new Date());gtag('config','UA-41201130-43');;
#   </script>
#   <link href="https://cdn.top-charts.com/static/css/main.min.css?9d2b8f9e" rel="stylesheet"/>
#   <link href="https://cdn.top-charts.com/static/css/navbar.min.css?10b69daf" rel="stylesheet"/>
#   <style>
#    @media (max-width: 992px) { .li:not(.show) { display: none; } .navbar-collapse { flex-basis: 0; width: fit-content; flex-grow: 0; } .navbar-brand { margin-right: 0; } .hide-992 { display: none !important; } .margin-hamb { margin-right: 8px; } } @media (max-width: 1200px) { .border-col-search { border-color: transparent !important; } } @media (min-width: 992px) { .show-992 { display: flex; } .flex-grow-992 { flex-grow: 1; } } .search-grad, .search-grad:before { background: linear-gradient(237.66deg, #813D3D 0%, #FF8D8D 100%); -webkit-background-clip: text; -webkit-text-fill-color: transparent; display: initial; /* reset Font Awesome's display:inline-block */ } /* background: linear-gradient(487.66deg, #f9f4f4, #fdd7d7 100%); */ .top-charts-header-font { width: 74px; color: #707d8a !important; font-size: 15px; font-weight: bold; line-height: 18px; } .image-on-bar { height: 53px; width: 52px; border-radius: 6px; background: linear-gradient(313.06deg, rgba(172, 38, 38, 0.5) 0%, rgba(255, 255, 255, 0) 37.87%, rgba(255, 255, 255, 0.25) 71.36%, rgba(255, 255, 255, 0.5) 100%); } .rank-position-icon { width: 19px; height: 19px; } @media (min-width: 576px) { .image-on-bar { height: 72px; width: 71px; } .rank-position-icon { height: 26px; width: auto; } } @media (min-width: 1200px) { .image-on-bar { height: 79px; width: 78px; } .rank-position-icon { height: 30px; width: auto; } } .song-card { border-radius: 5px; background-color: #FFFFFF; box-shadow: 0 1px 0 0 rgba(0, 0, 0, 0.09); } body { background-color: #F9F9F9; } .marg-alb-card { padding-top: 5px; padding-bottom: 5px; } .song-text { color: #6C6C6C; /*#383d41e3;*/ font-family: Roboto; font-size: 13px; font-weight: bold; line-height: 15px; margin-bottom: 2%; } @media (min-width: 576px) { .song-text { margin-bottom: 1%; font-size: 17px; line-height: 20px; } } @media (min-width: 992px) { .song-text { margin-bottom: 1%; font-size: 20px; line-height: 24px; } } @media (min-width: 1200px) { .song-text { font-size: 23px; font-weight: bold; line-height: 27px; } } .artist-text { color: #434343b5; font-family: Roboto; font-size: 12px; line-height: 14px; } @media (min-width: 576px) { .artist-text { font-size: 16px; line-height: 19px; } } @media (min-width: 576px) { .artist-text { font-size: 18px; line-height: 21px; } } @media (min-width: 1200px) { .artist-text { font-size: 20px; line-height: 24px; } } @media (max-width: 380px) { .no-wrap { flex-wrap: nowrap; } } .cont-song-margin { margin-left: 10px; margin-right: 10px; } @media (min-width: 576px) { .cont-song-margin { margin-left: 15px; margin-right: 15px; } } .songs-margin { margin-bottom: 5px; } .top-chart-title-style { background-color: white; box-shadow: 0 1px 0 0 rgba(0, 0, 0, .09); } @media (min-width: 576px) { .top-chart-title-style { margin-left: 15px; margin-right: 15px; border-radius: 5px; background-color: white; box-shadow: 0 1px 0 0 rgba(0, 0, 0, .09); } } .song-size { min-height: 60px; } @media (min-width: 576px) { .song-size { min-height: 80px; } } .container-img-text { position: relative; text-align: center; color: white; } /* Bottom left text */ .bottom-left { position: absolute; bottom: 8px; left: 16px; } /* Top left text */ .top-left { position: absolute; top: 8px; left: 16px; } /* Top right text */ .top-right { position: absolute; top: 8px; right: 16px; } /* Bottom right text */ .bottom-right { position: absolute; bottom: 8px; right: 16px; } /* Centered text */ .centered { position: absolute; top: 50%; left: 50%; transform: translate(-50%, -50%); } .play-icon-size { font-size: 30px; } @media (min-width: 1200px) { .play-icon-size { font-size: 45px; } } .icon-size-label { font-size: 35px; } .top-chart-title-text { background: -webkit-linear-gradient(130deg, rgba(178, 70, 70, 1) 0%, rgba(252, 114, 114, 0.72) 100%); -webkit-background-clip: text; -webkit-text-fill-color: transparent; font-family: Roboto; font-size: 15px; font-weight: 900; line-height: 18px; text-shadow: 1px 2px rgba(0, 0, 0, 0.1); } @media (min-width: 576px)  ...
#   </style>
#   <link href="https://fonts.googleapis.com/css?family=Lobster|Righteous|Roboto:400,700,900&amp;display=swap" rel="stylesheet"/>
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/5.11.2/css/all.css" rel="stylesheet"/>
#   <script src="https://code.jquery.com/jquery-3.4.1.slim.min.js">
#   </script>
#   <script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.7/umd/popper.min.js">
#   </script>
#   <script defer="" src="https://cdn.top-charts.com/static/js/packed.min.js?c0a8852b" type="text/javascript">
#   </script>
#   <meta content="{198664883831591}" property="fb:app_id"/>
#   <link href="https://www.top-charts.com/songs" hreflang="en" rel="alternate"/>
#   <link href="https://www.top-charts.com/pt/musicas" hreflang="pt" rel="alternate"/>
#   <link href="https://www.top-charts.com/es/canciones" hreflang="es" rel="alternate"/>
#   <link href="https://www.top-charts.com/songs" hreflang="x-default" rel="alternate"/>
#   <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <script>
#    window.googletag = window.googletag || {cmd: []};
#         googletag.cmd.push(function () {
#             var stickyMapping = googletag.sizeMapping().addSize([1200, 300], [[300, 600], [160, 600]]).// Desktop
#                 addSize([0, 0], []).build();
#
#             var MappingDesktopUnderMusic = googletag.sizeMapping().addSize([728, 45], [728, 90]).// Desktop
#                 addSize([0, 0], []).build();
#
#             var MappingDesktopUpPlatform = googletag.sizeMapping().addSize([1200, 100], [[336, 280], [300, 250]]).// Desktop
#                 addSize([0, 0], []).build();
#
#
#             // This mapping will only display ads when user is on mobile or tablet sized viewport
#             var MappingMobileHeader = googletag.sizeMapping().addSize([768, 90], []).addSize([320, 50], [320, 100]).// Tablet // Desktop
#                 addSize([0, 0], []).build();
#
#             var MappingMobileUnderMusic = googletag.sizeMapping().addSize([728, 90], []).// Desktop
#                 addSize([300, 125], [300, 250]).// Tablet
#                 addSize([0, 0], []).build();
#             if (window.innerWidth < 728) {
#                 googletag.defineSlot('/62660943/topcharts_mobile_homepage/topcharts_mobile_topsongs', [[320, 50], [320, 100]], 'div-gpt-ad-header').defineSizeMapping(MappingMobileHeader).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_mobile_homepage/topcharts_mobile_topsongs', [[300, 250]], 'div-gpt-ad-under-music-mob19').defineSizeMapping(MappingMobileUnderMusic).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_mobile_homepage/topcharts_mobile_topsongs', [[300, 250]], 'div-gpt-ad-under-music-mob39').defineSizeMapping(MappingMobileUnderMusic).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_mobile_homepage/topcharts_mobile_topsongs', [[300, 250]], 'div-gpt-ad-under-music-mob59').defineSizeMapping(MappingMobileUnderMusic).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_mobile_homepage/topcharts_mobile_topsongs', [[300, 250]], 'div-gpt-ad-under-music-mob79').defineSizeMapping(MappingMobileUnderMusic).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_mobile_homepage/topcharts_mobile_topsongs', [[300, 250]], 'div-gpt-ad-under-music-mob99').defineSizeMapping(MappingMobileUnderMusic).addService(googletag.pubads());
#             }
#             else {
#                 googletag.defineSlot('/62660943/topcharts_desktop_homepage/topcharts_desktop_stickyads', [[300, 600], [160, 600]], 'div-gpt-ad-sticky-ad').defineSizeMapping(stickyMapping).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_desktop_homepage/topcharts_desktop_topsongs', [[336, 280], [300, 250]], 'div-gpt-ad-up-platform').defineSizeMapping(MappingDesktopUpPlatform).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_desktop_homepage/topcharts_desktop_topsongs', [[728, 90]], 'div-gpt-ad-under-music-desk19').defineSizeMapping(MappingDesktopUnderMusic).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_desktop_homepage/topcharts_desktop_topsongs', [[728, 90]], 'div-gpt-ad-under-music-desk39').defineSizeMapping(MappingDesktopUnderMusic).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_desktop_homepage/topcharts_desktop_topsongs', [[728, 90]], 'div-gpt-ad-under-music-desk59').defineSizeMapping(MappingDesktopUnderMusic).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_desktop_homepage/topcharts_desktop_topsongs', [[728, 90]], 'div-gpt-ad-under-music-desk79').defineSizeMapping(MappingDesktopUnderMusic).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_desktop_homepage/topcharts_desktop_topsongs', [[728, 90]], 'div-gpt-ad-under-music-desk99').defineSizeMapping(MappingDesktopUnderMusic).addService(googletag.pubads());
#             }
#             googletag.pubads().enableSingleRequest();
#             googletag.pubads().collapseEmptyDivs();
#             googletag.enableServices();
#         });
#   </script>
#  </head>
#  <body>
#   <div id="fb-root">
#   </div>
#   <script async="" crossorigin="anonymous" defer="" src="https://connect.facebook.net/pt_PT/sdk.js#xfbml=1&amp;version=v5.0">
#   </script>
#   <link href="https://cdn.top-charts.com/static/css/top_songs.min.css?dae43232" rel="stylesheet" type="text/css"/>
#   <link href="https://cdn.top-charts.com/static/css/datetimepicker.min.css?74c5af5c" rel="stylesheet" type="text/css"/>
#   <header id="header" style="background-color: white">
#    <div class="container p-0 container-max-width">
#     <div class="container-fluid container-header-size">
#      <nav class="navbar navbar-expand-lg navbar-light navbar-details p-0 pt-lg-4" style="background-color: white">
#       <div class="row w-100 m-0 justify-content-between">
#        <div class="col-6 col-sm-5 col-lg-1">
#         <a class="navbar-brand pb-0" href="/">
#          <img alt="Top Charts" src="https://cdn.top-charts.com/static/images/logo_topcharts.svg" style="height: 33px"/>
#         </a>
#        </div>
#        <div class="col-6 col-sm-7 col-lg-6 col-xl-11 d-flex pr-0 flex-row-reverse flex-xl-row align-items-center align-items-xl-end justify-content-lg-around">
#         <div class="col-6 col-lg-7 adjust-max-width p-0 ml-sm-3">
#          <button aria-controls="navbarTogglerDemo02" aria-expanded="false" aria-label="Toggle navigation" class="border-col-search pl-0 no-outline hide-at-1200" data-target="#modalNavigation" data-toggle="modal" style="background-color: transparent;z-index: 2" type="button">
#           <i class="fas fa-align-justify search-grad">
#           </i>
#          </button>
#          <div class="show-at-1200 collapse navbar-collapse flex-lg-grow-0" id="navbarTogglerDemo02">
#           <ul class="navbar-nav mr-auto mt-2 mt-lg-0 flex-grow-1 justify-content-around align-items-center">
#            <li class="nav-item mx-1" id="/songs">
#             <a class="nav-link header header-titles-text header-text-active-border" href="/songs">
#              Top Songs
#              <span class="sr-only">
#               (current)
#              </span>
#             </a>
#            </li>
#            <li class="nav-item mx-1">
#             <a class="nav-link header-titles-text" href="/albums">
#              Top Albums
#             </a>
#            </li>
#            <li class="nav-item mx-1">
#             <a class="nav-link header-titles-text" href="/artists">
#              Artists
#             </a>
#            </li>
#            <li class="nav-item mx-1" id="/genres">
#             <a class="nav-link header-titles-text" href="/genres">
#              Genres
#             </a>
#            </li>
#            <li id="platform_dropdown">
#             <div class="dropdown header-titles-text">
#              <a class="dropdown-toggle header-titles-text" data-toggle="dropdown" role="button" type="button">
#               Platforms
#              </a>
#              <ul class="dropdown-menu dropdown-text" id="dropdownPlatforms">
#               <li class="dropdown-submenu hover-effect">
#                <a class="test" href="#" tabindex="-1">
#                 Apple Music
#                 <i class="fas fa-caret-right ml-1">
#                 </i>
#                </a>
#                <ul class="dropdown-menu dropdown-text">
#                 <li>
#                  <a href="/albums/all-genres/worldwide/apple-music" tabindex="-1">
#                   Albums
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/songs/all-genres/worldwide/apple-music" tabindex="-1">
#                   Songs
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li class="dropdown-submenu hover-effect">
#                <a class="test" href="#" tabindex="-1">
#                 iTunes
#                 <i class="fas fa-caret-right ml-1">
#                 </i>
#                </a>
#                <ul class="dropdown-menu dropdown-text">
#                 <li>
#                  <a href="/albums/all-genres/worldwide/itunes" tabindex="-1">
#                   Albums
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/songs/all-genres/worldwide/itunes" tabindex="-1">
#                   Songs
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li class="hover-effect">
#                <a href="/songs/all-genres/worldwide/radio" tabindex="-1">
#                 Radio Stations
#                </a>
#               </li>
#               <li class="hover-effect">
#                <a href="/songs/all-genres/worldwide/spotify" tabindex="-1">
#                 Spotify
#                </a>
#               </li>
#               <li class="dropdown-submenu hover-effect">
#                <a class="test" href="#" tabindex="-1">
#                 Top Charts
#                 <i class="fas fa-caret-right ml-1">
#                 </i>
#                </a>
#                <ul class="dropdown-menu dropdown-text">
#                 <li>
#                  <a href="/albums/all-genres/worldwide/total" tabindex="-1">
#                   Albums
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/songs/all-genres/worldwide/total" tabindex="-1">
#                   Songs
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li class="hover-effect">
#                <a href="/songs/all-genres/worldwide/youtube" tabindex="-1">
#                 Youtube
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#            <li class="nav-item mx-1" id="/map">
#             <a class="nav-link header-titles-text" href="/map">
#              Map
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="col-6 col-lg-4 p-0 d-flex flex-grow-1 fit-content-till-576">
#          <form action="/search" class="li form-inline search-icon my-lg-0 show w-100 show-at-576" method="get">
#           <div class="row m-0 header-search-border w-100">
#            <div class="input-group col-sm-12 pr-0 p-lg-0 mr-3">
#             <input class="form-control py-2 border-0 show-at-576 header-search-input" id="search-input" name="q" placeholder="Artist - Song - Album" type="text" value=""/>
#             <span class="input-group-append">
#              <button class="btn border-0" type="submit">
#               <i class="fa fa-search fa search-grad">
#               </i>
#              </button>
#             </span>
#            </div>
#           </div>
#          </form>
#          <form action="/search" class="li form-inline search-icon my-lg-0 show w-100 hide-at-576" method="get">
#           <div class="row header-search-border w-100">
#            <div class="input-group col-sm-12 pr-0 p-lg-0 mr-3">
#             <input class="form-control py-2 border-0 show-at-576 header-search-input" id="search-input" name="q" placeholder="Artist - Song - Album" type="text" value=""/>
#             <span class="input-group-append">
#              <button class="btn border-0" id="search" type="button">
#               <i class="fa fa-search fa search-grad">
#               </i>
#              </button>
#             </span>
#            </div>
#           </div>
#          </form>
#         </div>
#         <div class="col-lg-1 max-width-fit">
#          <div class="row m-0 align-items-baseline show-at-1200 generic-language">
#           <div class="col-4 max-width-fit px-1">
#            <div class="dropdown">
#             <button aria-expanded="false" aria-haspopup="true" class="btn btn-secondary dropdown-toggle generic-language-button pl-0" data-toggle="dropdown" id="dropdownMenuButton" type="button">
#              EN
#             </button>
#             <div aria-labelledby="dropdownMenuButton" class="dropdown-menu generic-language-dropdown">
#              <a class="dropdown-item color-grey" href="/pt/musicas">
#               PT
#              </a>
#              <a class="dropdown-item color-grey" href="/es/canciones">
#               ES
#              </a>
#              <a class="dropdown-item color-grey" href="/songs">
#               EN
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </nav>
#     </div>
#     <div aria-hidden="true" aria-labelledby="exampleModalLabel" class="modal fade" id="modalNavigation" role="dialog" tabindex="-1">
#      <div class="modal-dialog h-100 w-100 m-0" role="document">
#       <div class="modal-content w-100 h-100" style="background: linear-gradient(164.7deg, rgb(0, 0, 0) 0%, rgb(39, 9, 6) 100%);">
#        <div class="modal-header align-items-center">
#         <img alt="Top Charts" class="img-fluid" src="https://cdn.top-charts.com/static/images/logo_topcharts_modal.svg"/>
#         <button aria-label="Close" class="close" data-dismiss="modal" style="opacity: 1;" type="button">
#          <i class="far fa-times-circle" style="color: white; text-shadow: 0 0">
#          </i>
#         </button>
#        </div>
#        <div class="modal-body modal-list-hover p-0">
#         <nav class="list-group">
#          <div class="hamburger-links hamburger-text-style align-items-center px-3" onclick="showDropdown('dropdown1');addRemoveCaret('modal-option-1')" style="height: 48px">
#           <a class="list-group-item p-0" href="/songs">
#            Top Songs
#           </a>
#           <button aria-expanded="false" aria-haspopup="true" class="btn pr-1" style="color: white" type="button">
#            <i class="fas fa-caret-down" id="modal-option-1">
#            </i>
#           </button>
#          </div>
#          <div class="list-group" id="dropdown1" style="display: none;background: linear-gradient(133.29deg,
#                             rgba(252,114,114,0.72) 0%, #B24646 100%);">
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/songs/all-genres/worldwide/apple-music">
#             Apple Music Songs
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#           <div class="dropdown-divider modal-dropdown-margin">
#           </div>
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/songs/all-genres/worldwide/itunes">
#             iTunes Songs
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#           <div class="dropdown-divider modal-dropdown-margin">
#           </div>
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/songs/all-genres/worldwide/radio">
#             Radio songs
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#           <div class="dropdown-divider modal-dropdown-margin">
#           </div>
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/songs/all-genres/worldwide/spotify">
#             Spotify songs
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#           <div class="dropdown-divider modal-dropdown-margin">
#           </div>
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/songs/all-genres/worldwide/youtube">
#             Youtube
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#           <div class="dropdown-divider modal-dropdown-margin">
#           </div>
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/songs/all-genres/worldwide/total">
#             Total
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#          </div>
#          <div class="row m-0 hamburger-text-style modal-items-rows">
#           <a class="list-group-item modal-items" href="/genres">
#            Genres
#            <i aria-hidden="true" class="fas fa-caret-right" id="modal-option-4">
#            </i>
#           </a>
#          </div>
#          <div class="hamburger-links hamburger-text-style align-items-center px-3" onclick="showDropdown('dropdown2');addRemoveCaret('modal-option-2')" style="height: 48px">
#           <a class="list-group-item p-0">
#            Languages
#           </a>
#           <button aria-expanded="false" aria-haspopup="true" class="btn pr-1" style="color: white" type="button">
#            <i class="fas fa-caret-down" id="modal-option-2">
#            </i>
#           </button>
#          </div>
#          <div class="list-group" id="dropdown2" style="display: none;background: linear-gradient(133.29deg,
#                             rgba(252,114,114,0.72) 0%, #B24646 100%);">
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/pt/musicas">
#             Portuguese
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#           <div class="dropdown-divider modal-dropdown-margin">
#           </div>
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/es/canciones">
#             Spanish
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#           <div class="dropdown-divider modal-dropdown-margin">
#           </div>
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/songs">
#             English
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#          </div>
#          <div class="hamburger-links hamburger-text-style align-items-center px-3" onclick="showDropdown('dropdown3');addRemoveCaret('modal-option-3')" style=" height: 48px">
#           <a class="list-group-item p-0" href="/albums">
#            Top Albums
#           </a>
#           <button aria-expanded="false" aria-haspopup="true" class="btn pr-1" style="color: white" type="button">
#            <i class="fas fa-caret-down" id="modal-option-3">
#            </i>
#           </button>
#          </div>
#          <div class="list-group" id="dropdown3" style="display: none;background: linear-gradient(133.29deg,
#                             rgba(252,114,114,0.72) 0%, #B24646 100%);">
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/albums/all-genres/worldwide/apple-music">
#             Apple Music Albums
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#           <div class="dropdown-divider modal-dropdown-margin">
#           </div>
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/albums/all-genres/worldwide/itunes">
#             iTunes Albums
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#           <div class="dropdown-divider modal-dropdown-margin">
#           </div>
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/albums/all-genres/worldwide/total">
#             Top Albums
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#          </div>
#          <div class="row m-0 hamburger-text-style modal-items-rows" disabled="">
#           <a class="list-group-item modal-items" href="/artists">
#            Artists
#            <i aria-hidden="true" class="fas fa-caret-right" id="modal-option-3">
#            </i>
#           </a>
#          </div>
#          <div class="row m-0 hamburger-text-style modal-items-rows">
#           <a class="list-group-item modal-items" href="/map">
#            Map
#            <i aria-hidden="true" class="fas fa-caret-right" id="modal-option-4">
#            </i>
#           </a>
#          </div>
#         </nav>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="container mt-2 mb-2 hide-small-input" id="search-box">
#      <div class="row">
#       <div class="col-12">
#        <form action="/search" method="get">
#         <div class="input-group col-12 p-0">
#          <input class="form-control py-2 border-right-0 search-sug-placeholder" id="example-search-input" name="q" placeholder="Artist - Song - Album" style="box-shadow: inset 0 2px 1px 0 rgba(0,0,0,0.19);border-radius: 12px 0 0 12px;border: 0 !important;" type="search" value=""/>
#          <span class="input-group-append">
#           <button class="btn btn-outline-secondary border-left-0 border" style="border-radius: 0px 12px 12px 0px;
#                         box-shadow: inset -1px 2px 1px 0 rgba(0,0,0,0.19);
#                         background-color: white;
#                         border: 0 !important;" type="submit">
#            <i aria-hidden="true" class="fa fa-search fa search-grad" style="opacity: 0.50;">
#            </i>
#           </button>
#          </span>
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#   </header>
#   <div class="row m-0 container-border-genre">
#   </div>
#   <div class="row mx-0 justify-content-center hide-at-768 mb-1">
#    <div class="lawmaker-320-100" id="law-maker-2">
#     <div id="div-gpt-ad-header">
#      <script>
#       googletag.cmd.push(function () {
#                             googletag.display('div-gpt-ad-header');
#                         });
#      </script>
#     </div>
#    </div>
#   </div>
#   <div class="container-fluid hide-at-1200" style="background-color: white">
#    <div class="row align-items-center justify-content-between just row-title" style="box-shadow: 0 1px 0 0 rgba(0,0,0,.09);">
#     <div class="col-10 col-sm-10 top-chart-title-text">
#      <div class="row justify-content-cente align-items-center">
#       <div class="col-2 max-width-fit p-0 ml-3 mr-1 d-flex flex-row top-char-country-flag-expand">
#        <img alt="Spain" class="img-fluid top-country-flag-size" src="https://cdn.top-charts.com/static/countries/es.png"/>
#        <div class="overlay-grad-flag">
#        </div>
#       </div>
#       <div class="col-9 col-sm-10">
#        <div class="row">
#         <span class="top-chart-country-text">
#          Spain
#         </span>
#        </div>
#        <div class="row">
#         <span class="top-chart-title-text">
#          Top 100 Songs
#         </span>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="col-2 pl-0 max-width-fit text-right">
#      <img alt="android_ios" class="android-share share-button-img" data-target="#modalShare" data-toggle="modal" id="android" src="https://cdn.top-charts.com/static/images/Share_Android.svg"/>
#      <img alt="android_ios" class="ios-share share-button-img" data-target="#modalShare" data-toggle="modal" id="ios" src="https://cdn.top-charts.com/static/images/Share_IOS.svg"/>
#      <div aria-hidden="true" aria-labelledby="exampleModalLabel" class="modal fade" id="modalShare" role="dialog" tabindex="-1">
#       <div class="modal-dialog modal-share fixed-bottom w-100 m-0" role="document">
#        <div class="modal-content">
#         <div class="modal-header">
#          <div class="row align-items-center justify-content-sm-between just row-title w-100">
#           <div class="col-12 col-sm-12 top-chart-title-text">
#            <div class="row justify-content-cente align-items-center">
#             <div class="col-4 max-width-fit p-0 ml-3 mr-1 d-flex flex-row top-char-country-flag-expand">
#              <img alt="Spain" class="img-fluid top-country-flag-size" src="https://cdn.top-charts.com/static/countries/es.png"/>
#              <div class="overlay-grad-flag">
#              </div>
#             </div>
#             <div class="col-8">
#              <div class="row top-chart-country-text">
#               Spain
#              </div>
#              <div class="row top-chart-title-text">
#               Top 100 Songs
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#           <span aria-hidden="true">
#            ×
#           </span>
#          </button>
#         </div>
#         <div class="modal-body">
#          <div class="row flex-column flex-sm-row align-items-center">
#           <div class="col-4 text-center my-1 p-0">
#            <a aria-pressed="true" class="btn btn-primary share-buttons text-nowrap" href="http://www.facebook.com/sharer.php?u=https://www.top-charts.com/songs" role="button">
#             <i aria-hidden="true" class="fab fa-facebook-f song-dropdown-social-icons mr-1">
#             </i>
#             Facebook
#            </a>
#           </div>
#           <div class="col-4 text-center my-1 p-0">
#            <a aria-pressed="true" class="btn btn-primary share-buttons text-nowrap" href="http://twitter.com/share?text=https://www.top-charts.com/songs" role="button" style="min-width: 80px">
#             <i aria-hidden="true" class="fab fa-twitter song-dropdown-social-icons mr-1">
#             </i>
#             Twitter
#            </a>
#           </div>
#           <div class="col-4 text-center my-1 p-0">
#            <a aria-pressed="true" class="btn btn-primary share-buttons text-nowrap" href="https://api.whatsapp.com/send?text=https://www.top-charts.com/songs" role="button">
#             <i aria-hidden="true" class="fab fa-whatsapp song-dropdown-social-icons mr-1">
#             </i>
#             Whatsapp
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="container-fluid d-flex flex-column justify-content-center top-songs-grad-box justify-content-xl-center">
#    <div class="row justify-content-xl-center align-items-xl-center show-at-1200">
#     <div class="col-xl-2 max-width-fit p-0 ml-3 mr-1 mb-1 d-flex flex-row top-char-country-flag-expand align-self-end">
#      <img alt="country" class="img-fluid top-country-flag-size-with-border" src="https://cdn.top-charts.com/static/countries/es.png"/>
#      <div class="overlay-grad-flag">
#      </div>
#     </div>
#     <div class="col-xl-10 max-width-fit">
#      <h1 style="font-size: 0">
#       <span class="grad-logos-text-small">
#        Spain
#       </span>
#       <br/>
#       <span class="top-search-title-style top-search-line">
#        Top 100 Songs
#       </span>
#      </h1>
#     </div>
#    </div>
#    <div class="row m-0 mb-2 justify-content-center">
#     <div class="container-max-width-1200 w-100">
#      <div class="col-12 p-0">
#       <form>
#        <div class="form-group row mx-sm-0 align-items-center justify-content-md-center mb-2 mb-xl-3">
#         <label class="px-1 col-3 col-md-2 col-xl-3 text-truncate col-form-label text-center text-xl-right pr-xl-60 top-search-form-labels" for="week">
#          The Week of
#         </label>
#         <div class="mr-3 form-cols" id="week_of">
#          <div class="input-group form-control top-search-form-placeholders form-border-radius" id="DateDemo">
#           <input class="top-search-form-placeholders w-100 text-truncate" id="weeklyDatePicker" onclick="addColorToSelectedWeek()" placeholder="Select Week" type="text"/>
#          </div>
#         </div>
#        </div>
#        <div class="form-group row mx-sm-0 align-items-center justify-content-md-center mb-2 mb-xl-3 flex-nowrap">
#         <label class="pr-1 col-3 col-md-2 col-xl-3 text-truncate text-center text-xl-right pr-xl-60 col-form-label top-search-form-labels" for="genre">
#          Genre
#         </label>
#         <div class="mr-3 form-cols" id="genre_col">
#          <select class="form-control pr-45 round top-search-form-placeholders form-border-radius text-truncate" id="genre" name="genre">
#           <option value="all-genres">
#            All Genres
#           </option>
#           <option value="alternative">
#            Alternative
#           </option>
#           <option value="blues">
#            Blues
#           </option>
#           <option value="christian-gospel">
#            Christian &amp; Gospel
#           </option>
#           <option value="classical">
#            Classical
#           </option>
#           <option value="country">
#            Country
#           </option>
#           <option value="dance">
#            Dance
#           </option>
#           <option value="electronic">
#            Electronic
#           </option>
#           <option value="hip-hop-rap">
#            Hip-Hop/Rap
#           </option>
#           <option value="jazz">
#            Jazz
#           </option>
#           <option value="latin">
#            Latin
#           </option>
#           <option value="pop">
#            Pop
#           </option>
#           <option value="rb-soul">
#            R&amp;B/Soul
#           </option>
#           <option value="reggae">
#            Reggae
#           </option>
#           <option value="rock">
#            Rock
#           </option>
#           <option value="world">
#            World
#           </option>
#          </select>
#         </div>
#        </div>
#        <div class="form-group row mx-sm-0 align-items-center justify-content-md-center mb-2 mb-xl-3">
#         <label class="col-3 col-md-2 col-xl-3 text-truncate pr-1 text-center text-xl-right pr-xl-60 col-form-label top-search-form-labels" for="country">
#          Country
#         </label>
#         <div class="mr-3 form-cols" id="country_col">
#          <select class="form-control round pr-45 top-search-form-placeholders form-border-radius" id="country" name="country">
#           <option value="spain">
#            Spain
#           </option>
#           <option value="argentina">
#            Argentina
#           </option>
#           <option value="australia">
#            Australia
#           </option>
#           <option value="austria">
#            Austria
#           </option>
#           <option value="belgium">
#            Belgium
#           </option>
#           <option value="brazil">
#            Brazil
#           </option>
#           <option value="canada">
#            Canada
#           </option>
#           <option value="chile">
#            Chile
#           </option>
#           <option value="colombia">
#            Colombia
#           </option>
#           <option value="czech-republic">
#            Czech Republic
#           </option>
#           <option value="denmark">
#            Denmark
#           </option>
#           <option value="egypt">
#            Egypt
#           </option>
#           <option value="finland">
#            Finland
#           </option>
#           <option value="france">
#            France
#           </option>
#           <option value="germany">
#            Germany
#           </option>
#           <option value="greece">
#            Greece
#           </option>
#           <option value="hungary">
#            Hungary
#           </option>
#           <option value="india">
#            India
#           </option>
#           <option value="indonesia">
#            Indonesia
#           </option>
#           <option value="ireland">
#            Ireland
#           </option>
#           <option value="israel">
#            Israel
#           </option>
#           <option value="italy">
#            Italy
#           </option>
#           <option value="japan">
#            Japan
#           </option>
#           <option value="malaysia">
#            Malaysia
#           </option>
#           <option value="mexico">
#            Mexico
#           </option>
#           <option value="netherlands">
#            Netherlands
#           </option>
#           <option value="new-zealand">
#            New Zealand
#           </option>
#           <option value="nigeria">
#            Nigeria
#           </option>
#           <option value="norway">
#            Norway
#           </option>
#           <option value="peru">
#            Peru
#           </option>
#           <option value="philippines">
#            Philippines
#           </option>
#           <option value="poland">
#            Poland
#           </option>
#           <option value="portugal">
#            Portugal
#           </option>
#           <option value="singapore">
#            Singapore
#           </option>
#           <option value="south-africa">
#            South Africa
#           </option>
#           <option value="south-korea">
#            South Korea
#           </option>
#           <option value="sweden">
#            Sweden
#           </option>
#           <option value="switzerland">
#            Switzerland
#           </option>
#           <option value="taiwan">
#            Taiwan
#           </option>
#           <option value="thailand">
#            Thailand
#           </option>
#           <option value="turkey">
#            Turkey
#           </option>
#           <option value="ukraine">
#            Ukraine
#           </option>
#           <option value="united-arab-emirates">
#            United Arab Emirates
#           </option>
#           <option value="united-kingdom">
#            United Kingdom
#           </option>
#           <option value="united-states">
#            United States
#           </option>
#           <option value="vietnam">
#            Vietnam
#           </option>
#           <option value="worldwide">
#            Worldwide
#           </option>
#          </select>
#         </div>
#        </div>
#       </form>
#      </div>
#      <div class="row mx-0 align-items-center justify-content-end justify-content-md-center mt-n1">
#       <div class="pr-sm-3 pr-md-2 pr-xl-4 mr-xl-2 col-md-8 p-0 methodology d-flex justify-content-end align-items-center">
#        <div class="mx-2">
#         <a href="/csv/all-genres/spain/total">
#          Download To CSV
#          <i class="ml-2 fas fa-download">
#          </i>
#          ,
#         </a>
#        </div>
#        <div class="d-flex flex-row justify-content-end">
#         <div class="row mr-1 max-width-fit m-0 align-items-center justify-content-end flex-nowrap" data-original-title="The Top 100 Songs chart ranks the most played songs of the week in 46 countries. The chart includes airplay from 15000 radio stations , iTunes downloads, Apple Music, Spotify and Youtube streams. The rank is updated weekly." data-placement="top" data-toggle="tooltip" title="">
#          <span class="mr-2">
#           Methodology
#          </span>
#          <img alt="methodology" class="methodology-icon" src="/static/images/methodology_icon.svg"/>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="container p-0 m-0 mt-n4 mx-sm-auto mx-xl-auto px-xl-0 container-max-width">
#    <div class="container-fluid mb-2 p-xl-0">
#     <div class="d-none">
#      <ul class="breadcrumb" itemscope="" itemtype="http://schema.org/BreadcrumbList">
#       <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#        <a href="/songs" itemprop="item">
#         <span itemprop="name">
#          Songs
#         </span>
#        </a>
#        <meta content="1" itemprop="position"/>
#       </li>
#       <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#        <a href="/songs" itemprop="item">
#         <span itemprop="name">
#          All Genres
#         </span>
#        </a>
#        <meta content="2" itemprop="position"/>
#       </li>
#       <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#        <a href="/songs" itemprop="item">
#         <span itemprop="name">
#          Spain
#         </span>
#        </a>
#        <meta content="3" itemprop="position"/>
#       </li>
#       <li itemscope="" itemtype="http://schema.org/ListItem" property="itemListElement">
#        <a href="/songs" itemprop="item">
#         <span itemprop="name">
#          Total
#         </span>
#        </a>
#        <meta content="4" itemprop="position"/>
#       </li>
#      </ul>
#     </div>
#     <div class="row song-card songs-margin song-size align-items-center justify-content-between mx-n1 mx-sm-0" id="s1" itemscope="" itemtype="http://schema.org/MusicGroup">
#      <div class="col-10 d-flex align-items-center pl-0">
#       <div class="col-1 align-middle text-center info-detail-artist-numbers numbers-min-width max-width-fit p-0 ml-lg-2">
#        <span>
#         1
#        </span>
#       </div>
#       <div class="col-3 marg-alb-card mr-sm-1 img-size pl-0 pr-1 px-lg-2" onclick="playSelectedSong(0)">
#        <div class="container-img-text">
#         <img alt="Pareja Del Año artwork" class="image-on-bar" data-src="https://is5-ssl.mzstatic.com/image/thumb/Music114/v4/ff/8b/6c/ff8b6c97-11f3-9f3f-c441-30887275da82/21UMGIM25076.rgb.jpg/60x60bb.jpeg" src="https://cdn.top-charts.com/static/images/loading.gif"/>
#         <img alt="play" class="centered song-card-play-button" id="1-img" src="https://cdn.top-charts.com/static/images/BT_Play.png"/>
#        </div>
#       </div>
#       <div class="col-8">
#        <div class="row song-text" id="title" style="">
#         <div class="col-12 p-0">
#          <span class="song-text" itemprop="track" itemscope="" itemtype="http://schema.org/MusicRecording">
#           <a href="/s/pareja-del-ano-sebastian-yatra-myke-towers" itemprop="url">
#            <div class="text-truncate" itemprop="name">
#             Pareja Del Año
#            </div>
#           </a>
#          </span>
#         </div>
#        </div>
#        <div class="row artist-text text-color-sing" id="Artist">
#         <div class="col-12 p-0 text-truncate d-block">
#          <a href="/artist-detail/myke-towers" itemprop="url">
#           <span itemprop="name">
#            Myke Towers,
#           </span>
#          </a>
#          <a href="/artist-detail/sebastian-yatra" itemprop="url">
#           <span itemprop="name">
#            Sebastián Yatra
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="col-2 d-flex align-items-center justify-content-center">
#       <div class="btn-group dropdown">
#        <button aria-expanded="false" aria-haspopup="true" class="btn dropdown-toggle-split" onclick="showSongInfoDropDown(1);addRemoveCaret('caret1')" type="button">
#         <i class="fas fa-caret-up caret-active drop-colour drop-icon-size" id="caret1">
#         </i>
#        </button>
#       </div>
#      </div>
#      <div class="flex-column" id="1" style="width: 100%;">
#       <ul class="nav nav-tabs nav-fill" id="myTab" role="tablist">
#        <li class="nav-item">
#         <a aria-controls="home" aria-selected="true" class="nav-link active song-dropdown-options song-dropdown-options-active px-0" data-toggle="tab" href="#stats" id="stats-tab" onclick="showActiveTabs(this.id,'','')" role="tab">
#          STATS
#         </a>
#        </li>
#        <li class="nav-item">
#         <a aria-controls="profile" aria-selected="false" class="nav-link song-dropdown-options px-0" data-toggle="tab" href="#share" id="share-tab" onclick="showActiveTabs(this.id,'','')" role="tab">
#          SHARE
#         </a>
#        </li>
#        <li class="nav-item">
#         <a aria-controls="contact" aria-selected="false" class="nav-link song-dropdown-options px-0" data-toggle="tab" href="#go-to" id="go-to-tab" onclick="showActiveTabs(this.id,'','')" role="tab">
#          GO TO
#         </a>
#        </li>
#       </ul>
#       <div class="tab-content dropdown-info-size d-flex align-items-center" id="myTabContent">
#        <div aria-labelledby="stats-tab" class="tab-pane w-100 row m-0 fade show active" id="stats" role="tabpanel">
#         <div class="row m-0">
#          <div class="col-12 col-sm-8 col-xl-7 p-0 d-flex justify-content-around pt-2 d-flex flex-column">
#           <div class="row m-0">
#            <div class="col-4 p-0 width">
#             <div class="row m-0 info-card-song-stats mb-1 justify-content-center">
#              <span>
#               Last week
#              </span>
#             </div>
#             <div class="row m-0 justify-content-center info-card-song-numbers">
#              <span>
#               1
#              </span>
#             </div>
#            </div>
#            <div class="col-4 p-0 width">
#             <div class="row m-0 info-card-song-stats mb-1 justify-content-center">
#              <span>
#               Peak Position
#              </span>
#             </div>
#             <div class="row m-0 justify-content-center info-card-song-numbers">
#              <span>
#               1
#              </span>
#             </div>
#            </div>
#            <div class="col-4 p-0 width">
#             <div class="row m-0 info-card-song-stats mb-1 justify-content-center">
#              <span>
#               Weeks on chart
#              </span>
#             </div>
# ...
#   </script>
#   <script id="first_music" type="application/json">
#    {"position": 1, "song": {"song_id": 1561274161, "name": "Pareja Del A\u00f1o", "artist_name": "Sebasti\u00e1n Yatra \u0026 Myke Towers", "present_in_top": true, "rating": "", "artists_slugs": [{"artist_name": "Myke Towers", "artist_slug": "myke-towers"}, {"artist_name": "Sebasti\u00e1n Yatra", "artist_slug": "sebastian-yatra"}], "artwork_url_small": "https://is5-ssl.mzstatic.com/image/thumb/Music114/v4/ff/8b/6c/ff8b6c97-11f3-9f3f-c441-30887275da82/21UMGIM25076.rgb.jpg/60x60bb.jpeg", "artwork_url_large": "https://is5-ssl.mzstatic.com/image/thumb/Music114/v4/ff/8b/6c/ff8b6c97-11f3-9f3f-c441-30887275da82/21UMGIM25076.rgb.jpg/170x170bb.jpeg", "release": "2021-04-16", "apple_music_view_url": "https://geo.music.apple.com/at/album/pareja-del-a%C3%B1o/1561274157?i=1561274161\u0026app=music\u0026mt=1\u0026at=11l64h\u0026ct=top-charts", "itunes_view_url": "https://geo.music.apple.com/at/album/pareja-del-a%C3%B1o/1561274157?i=1561274161\u0026app=itunes\u0026mt=1\u0026at=11l64h\u0026ct=top-charts", "preview_url": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview114/v4/95/53/51/95535168-a155-6255-eed4-0ac797541e61/mzaf_7494692085491664332.plus.aac.p.m4a", "slug": "pareja-del-ano-sebastian-yatra-myke-towers"}, "peak_position": 1, "last_week": {"position": 1, "image": ""}, "weeks_chart": 3}
#   </script>
#   <script defer="">
#    var first_music = ("first music", JSON.parse(document.getElementById('first_music').textContent));
#         var songs = JSON.parse(document.getElementById('songs').textContent);
#
#         songs.unshift(first_music);
#   </script>
#   <script defer="">
#    var audio;
#         var volume = 1;
#         var checker = 0;
#         var old_key = 0;
#         var song_array;
#         let current = 0;
#         var isAfter;
#
#
#         $('#audio-player').hide();
#         //Hide Pause
#         $('#pause').hide();
#
#         function initAudio() {
#
#
#             var song = song_array['preview_url'];
#             var title = song_array['name'];
#             var cover = song_array['artwork_url_large'];
#             var slug = song_array['slug'];
#             var artist = song_array['artist_name'];
#             var apple_music = song_array['apple_music_view_url'];
#             var itunes = song_array['itunes_view_url'];
#
#
#             //Create audio object
#             audio = new Audio(song);
#             audio.volume = volume;
#
#             audio.play().then(() => {
#                 $('#play').hide();
#                 $('#pause').show();
#                 showDuration();
#                 afterSongEnd();
#             }).catch(err => {
#                 if (isAfter) {
#                     return noPreviewUrl();
#                 }
#                 return noPreviewUrlBack(err);
#             });
#
#             //Insert audio info
#             $('.audio-song-artists').text(artist);
#             $('.audio-song-title').text(title);
#             $('#audio-itunes').attr('href', itunes);
#             $('#audio-song-href').attr('href', '/s/' + slug);
#             $('#audio-apple-music').attr('href', apple_music);
#             $('#audio-small-apple-music').attr('href', apple_music);
#             switchPlayImage();
#
#             //Insert song cover
#             $('img.audio-song-image').attr('src', cover);
#
#
#
#         }
#
#         function switchPlayImage() {
#             let value = current + 1;
#             if (checker === 0) {
#                 $("#" + value + "-img").attr('src', "https://cdn.top-charts.com/static/images/player_icons/audio_play.gif");
#                 checker++;
#                 old_key = current + 1
#             } else {
#
#                 $('#' + old_key + '-img').attr('src', "https://cdn.top-charts.com/static/images/BT_Play.png");
#                 old_key = value;
#                 $("#" + value + "-img").attr('src', "https://cdn.top-charts.com/static/images/player_icons/audio_play.gif");
#
#             }
#         }
#
#
#         //Play button
#         $('#play').click(function () {
#             audio.play();
#             $('#' + (current + 1) + '-img').attr('src', "https://cdn.top-charts.com/static/images/player_icons/audio_play.gif");
#             $('#play').hide();
#             $('#pause').show();
#             afterSongEnd();
#             showDuration();
#
#         });
#
#         //Pause button
#         $('#pause').click(function () {
#             audio.pause();
#             $('#' + (current + 1) + '-img').attr('src', "https://cdn.top-charts.com/static/images/BT_Play.png");
#             $('#play').show();
#             $('#pause').hide();
#         });
#
#         //Stop button
#         $('#stop').click(function () {
#             audio.pause();
#             audio.currentTime = 0;
#         });
#
#         //Next button
#         $('#next').click(function () {
#             isAfter = true;
#             audio.pause();
#             var next = current + 1;//position differs one pos more then normal array
#             //end of playlist
#             if (current === 99) {
#                 next = 0;
#             }
#             song_array = songs[next]['song'];
#             current = next;
#             initAudio();
#
#         });
#
#         //Prev button
#         $('#prev').click(function () {
#             isAfter = false;
#             audio.pause();
#             var previous = current - 1;//position differs two pos from array
#             //end of playlist
#             if (previous <= 0) {
#                 previous = 0;
#             }
#             song_array = songs[previous]['song'];
#             current = previous;
#             initAudio();
#         });
#
#         //Playlist song click
#         function playSelectedSong(id) {
#             marginFooterAudio();
#             $('#audio-player').show();
#             if (audio) {
#                 audio.pause();
#             }
#             current = id;
#             song_array = songs[id]['song'];
#             initAudio();
#
#         }
#
#
#         //Time/Duration
#         function showDuration() {
#             $(audio).bind('timeupdate', function () {
#                 //Get hours and minutes
#                 var s = parseInt(audio.currentTime % 60);
#                 var m = parseInt(audio.currentTime / 60) % 60;
#                 if (s < 10) {
#                     s = '0' + s;
#                 }
#                 $('#duration').html(m + ':' + s);
#                 var value = 0;
#                 if (audio.currentTime > 0) {
#                     value = Math.floor((100 / audio.duration) * audio.currentTime);
#                 }
#                 $('#ex1Slider .slider-selection ').css('width', value + '%');
#                 $('#ex1Slider .slider-handle').css('left', value + '%');
#             });
#         }
#
#         function afterSongEnd() {
#             $(audio).on('ended', function () {
#
#                 //Get hours and minutes
#
#                 if (audio.ended) {
#                     var next = current + 1;
#                     //end of playlist
#                     if (current === 98) {
#                         next = 0;
#                     }
#                     song_array = songs[next]['song'];
#                     current = next;
#                     initAudio();
#                 }
#             })
#         }
#
#
#         $(document).ready(function () {
#             $('#ex1').slider({
#                 formatter: function (value) {
#                 }
#             });
#         });
#
#
#
#
#          $('#ex1').on('slideStop', function (event) {
#             audio.currentTime = event.value;
#         });
#
#
#         $('#sound').on('click', function (event) {
#             if (audio.volume === 0) {
#                 audio.volume = volume;
#
#                 $('#ex2Slider .slider-selection ').css('width', audio.volume * 100 + '%');
#                 $('#ex2Slider .slider-handle').css('left', audio.volume * 100 + '%');
#                 return 0;
#             }
#             audio.volume = 0;
#             $('#ex2Slider .slider-selection ').css('width', 0 + '%');
#             $('#ex2Slider .slider-handle').css('left', 0 + '%');
#
#
#         });
#   </script>
#   <script>
#    function noPreviewUrl(err) {
#             var next = current + 1;
#             //end of playlist
#             if (current === 98) {
#                 next = 0;
#             }
#             song_array = songs[next]['song'];
#             current = next;
#             isAfter = true;
#             initAudio();
#         }
#
#         function noPreviewUrlBack(err) {
#             console.log(err);
#             var next = current - 1;
#             //end of playlist
#             if (current === 0) {
#                 next = 1;
#             }
#             song_array = songs[next]['song'];
#             current = next;
#             isAfter = false;
#             initAudio();
#
#         }
#   </script>
#   <script>
#    $(document).ready(function () {
#             $('.dropdown-submenu').hover(function (e) {
#                 console.log("elemento", $(this).children('ul'));
#                 $(this).children('ul').toggle();
#                 e.stopPropagation();
#                 e.preventDefault();
#             });
#         });
#   </script>
#   <script defer="">
#    function showActiveTabs(elementId, key, position) {
#             var style = "song-dropdown-options-active";
#             //Activate class on elementId and remove on others
#             $("#share-tab" + key + position).removeClass(style);
#             $("#stats-tab" + key + position).removeClass(style);
#             $("#go-to-tab" + key + position).removeClass(style);
#             $('#' + elementId).addClass(style);
#         }
#   </script>
#   <script defer="">
#    $(document).ready(function () {
#             $("img").unveil(200);
#         });
#   </script>
#   <script defer="">
#    $(document).ready(function () {
#             $('#ex2').slider({
#                 formatter: function (value) {
#
#                 }
#             });
#         });
#
#         $('#ex2').on('change', function (event) {
#             console.log('changed');
#             if (audio) {
#                 audio.volume = event.value.newValue/100;
#             }
#         });
#   </script>
#   <script defer="">
#    $(document).ready(function () {
#             $('[data-toggle="tooltip"]').tooltip();
#         });
#   </script>
#   <script defer="">
#    function addRemoveCaret(id) {
#
#             var element = document.getElementById(id);
#
#             if (element.classList.contains("fa-caret-down")) {
#                 element.classList.remove("fa-caret-down");
#                 element.classList.add("caret-active");
#                 element.classList.add("fa-caret-up");
#             } else {
#                 element.classList.remove("caret-active");
#                 element.classList.remove("fa-caret-up");
#                 element.classList.add("fa-caret-down");
#             }
#         }
#   </script>
#   <script>
#    function showDropdown(elementId) {
#             var x = document.getElementById(elementId);
#             if (x.style.display === "none") {
#                 x.style.display = "block";
#             } else {
#                 x.style.display = "none";
#             }
#         }
#   </script>
#   <script>
#    document.getElementById("search").addEventListener("click", redSearch, false);
#
#         function redSearch() {
#             var x = document.getElementById("search");
#             if (x.classList.contains('search-icon')) {
#                 x.classList.remove("search-icon");
#                 x.classList.add("box-shadow-0");
#             } else {
#                 x.classList.add("search-icon");
#             }
#         }
#   </script>
#   <script>
#    document.getElementById("search").addEventListener("click", showSearchContainer, false);
#
#         function showSearchContainer() {
#
#             var x = document.getElementById("search-box");
#
#             if (x.style.display === "none" || getComputedStyle(x, null).display === 'none') {
#                 x.style.display = "block";
#             } else {
#                 x.style.display = "none";
#             }
#         }
#   </script>
#   <script>
#    function marginFooterAudio() {
#             if (screen.width >= 576) {
#                 $("footer").css('margin-bottom', 68 + 'px');
#                 return 0;
#             }
#             $("footer").css('margin-bottom', 55 + 'px');
#
#         }
#   </script>
#  </body>
# </html>

# %%
soup.select("#title > div > span > a > div")
# Out:
# [<div class="text-truncate" itemprop="name">Pareja Del Año</div>,
#  <div class="text-truncate" itemprop="name">Fiel</div>,
#  <div class="text-truncate" itemprop="name">Flamenco y Bachata</div>,
#  <div class="text-truncate" itemprop="name">AM</div>,
#  <div class="text-truncate" itemprop="name">Búmeran</div>,
#  <div class="text-truncate" itemprop="name">911</div>,
#  <div class="text-truncate" itemprop="name">EL MAKINON</div>,
#  <div class="text-truncate" itemprop="name">Snow Tha Product: Bzrp Music Sessions, Vol. 39</div>,
#  <div class="text-truncate" itemprop="name">Tú Me Dejaste de Querer (feat. Niño de Elche &amp; La Húngara)</div>,
#  <div class="text-truncate" itemprop="name">Solo</div>,
#  <div class="text-truncate" itemprop="name">Bandido</div>,
#  <div class="text-truncate" itemprop="name">Me Fijé</div>,
#  <div class="text-truncate" itemprop="name">Aloha (feat. Darell, Mambo Kingz &amp; DJ Luian)</div>,
#  <div class="text-truncate" itemprop="name">Ram Pam Pam</div>,
#  <div class="text-truncate" itemprop="name">Ella No Es Tuya (Remix)</div>,
#  <div class="text-truncate" itemprop="name">Juramento eterno de sal</div>,
#  <div class="text-truncate" itemprop="name">The Four Horsemen</div>,
#  <div class="text-truncate" itemprop="name">Location</div>,
#  <div class="text-truncate" itemprop="name">MONTERO (Call Me By Your Name)</div>,
#  <div class="text-truncate" itemprop="name">2/Catorce</div>,
#  <div class="text-truncate" itemprop="name">Ni Una Más</div>,
#  <div class="text-truncate" itemprop="name">LA NOCHE DE ANOCHE</div>,
#  <div class="text-truncate" itemprop="name">Through the Roof</div>,
#  <div class="text-truncate" itemprop="name">Peaches (feat. Daniel Caesar &amp; GIVĒON)</div>,
#  <div class="text-truncate" itemprop="name">Friday (feat. Mufasa &amp; Hypeman) [Dopamine Re-Edit]</div>,
#  <div class="text-truncate" itemprop="name">512</div>,
#  <div class="text-truncate" itemprop="name">PIN PIN</div>,
#  <div class="text-truncate" itemprop="name">The Little Giant</div>,
#  <div class="text-truncate" itemprop="name">Dakiti</div>,
#  <div class="text-truncate" itemprop="name">La Historia</div>,
#  <div class="text-truncate" itemprop="name">Travesuras (feat. Wisin &amp; Yandel, Myke Towers &amp; Flow La Movie) [Remix]</div>,
#  <div class="text-truncate" itemprop="name">Sevilla Mundial</div>,
#  <div class="text-truncate" itemprop="name">Vida de Rico</div>,
#  <div class="text-truncate" itemprop="name">Turandot: Nessun doma!</div>,
#  <div class="text-truncate" itemprop="name">Millones</div>,
#  <div class="text-truncate" itemprop="name">Ingobernable</div>,
#  <div class="text-truncate" itemprop="name">Las Nenas (feat. La Duraca)</div>,
#  <div class="text-truncate" itemprop="name">The Ecstasy of Gold from "The Good the Bad and the Ugly"</div>,
#  <div class="text-truncate" itemprop="name">Baila Conmigo</div>,
#  <div class="text-truncate" itemprop="name">Vaudeville</div>,
#  <div class="text-truncate" itemprop="name">Save Your Tears (Remix)</div>,
#  <div class="text-truncate" itemprop="name">MÍRENME AHORA</div>,
#  <div class="text-truncate" itemprop="name">Ra, Ra, Ra</div>,
#  <div class="text-truncate" itemprop="name">No me lo creo</div>,
#  <div class="text-truncate" itemprop="name">Amor en Coma</div>,
#  <div class="text-truncate" itemprop="name">Sal y Perrea</div>,
#  <div class="text-truncate" itemprop="name">Wao</div>,
#  <div class="text-truncate" itemprop="name">Northwest Wind</div>,
#  <div class="text-truncate" itemprop="name">La Curiosidad</div>,
#  <div class="text-truncate" itemprop="name">KESI</div>,
#  <div class="text-truncate" itemprop="name">El Partidazo (COPE)</div>,
#  <div class="text-truncate" itemprop="name">Real Apps</div>,
#  <div class="text-truncate" itemprop="name">Vida de Rico</div>,
#  <div class="text-truncate" itemprop="name">Bringing the Happy</div>,
#  <div class="text-truncate" itemprop="name">L-Gante: Bzrp Music Sessions, Vol.38</div>,
#  <div class="text-truncate" itemprop="name">Sudores fríos</div>,
#  <div class="text-truncate" itemprop="name">Your Power</div>,
#  <div class="text-truncate" itemprop="name">Levitating (feat. DaBaby)</div>,
#  <div class="text-truncate" itemprop="name">Hopeful Road</div>,
#  <div class="text-truncate" itemprop="name">De Pies a Cabeza</div>,
#  <div class="text-truncate" itemprop="name">Fellini's Stories</div>,
#  <div class="text-truncate" itemprop="name">Explícito</div>,
#  <div class="text-truncate" itemprop="name">Vuelve, Vuelve</div>,
#  <div class="text-truncate" itemprop="name">My Head &amp; My Heart</div>,
#  <div class="text-truncate" itemprop="name">Machu Picchu</div>,
#  <div class="text-truncate" itemprop="name">Conexión (feat. Bryant Myers, Eladio Carrión &amp; Tory Lanez)</div>,
#  <div class="text-truncate" itemprop="name">Christian Dior</div>,
#  <div class="text-truncate" itemprop="name">Hypnotized</div>,
#  <div class="text-truncate" itemprop="name">La Nota</div>,
#  <div class="text-truncate" itemprop="name">Canción Bonita</div>,
#  <div class="text-truncate" itemprop="name">Skippety Skip, Pt. 2</div>,
#  <div class="text-truncate" itemprop="name">Decidida</div>,
#  <div class="text-truncate" itemprop="name">News Flash</div>,
#  <div class="text-truncate" itemprop="name">Hecha Pa' Mi</div>,
#  <div class="text-truncate" itemprop="name">A un passo dalla luna</div>,
#  <div class="text-truncate" itemprop="name">Rainbow Riders</div>,
#  <div class="text-truncate" itemprop="name">La Cartita</div>,
#  <div class="text-truncate" itemprop="name">Diamonds</div>,
#  <div class="text-truncate" itemprop="name">La Mamá de la Mamá (feat. El Cherry Scom)</div>,
#  <div class="text-truncate" itemprop="name">La promesa</div>,
#  <div class="text-truncate" itemprop="name">LE GUSTA QUE LA VEAN</div>,
#  <div class="text-truncate" itemprop="name">You Need To Calm Down</div>,
#  <div class="text-truncate" itemprop="name">Big Sky</div>,
#  <div class="text-truncate" itemprop="name">Amoralí (with Potito)</div>,
#  <div class="text-truncate" itemprop="name">Tiroteo (Remix)</div>,
#  <div class="text-truncate" itemprop="name">11 RAZONES</div>,
#  <div class="text-truncate" itemprop="name">Otra Noche Sin Ti</div>,
#  <div class="text-truncate" itemprop="name">EL PONY</div>,
#  <div class="text-truncate" itemprop="name">Beautiful Cells</div>,
#  <div class="text-truncate" itemprop="name">A Un Paso De La Luna</div>,
#  <div class="text-truncate" itemprop="name">Porfa no te vayas</div>,
#  <div class="text-truncate" itemprop="name">Dynamite</div>,
#  <div class="text-truncate" itemprop="name">Ringui Dingui (feat. SFDK)</div>,
#  <div class="text-truncate" itemprop="name">Play Ball</div>,
#  <div class="text-truncate" itemprop="name">I Promised Myself</div>,
#  <div class="text-truncate" itemprop="name">Kiss Me More (feat. SZA)</div>,
#  <div class="text-truncate" itemprop="name">Jerusalema (feat. Nomcebo Zikode) [Edit]</div>,
#  <div class="text-truncate" itemprop="name">Poblado</div>,
#  <div class="text-truncate" itemprop="name">Sonqueson</div>,
#  <div class="text-truncate" itemprop="name">Inside News</div>]

# %%
soup.select("div.text-truncate")
# Out:
# [<div class="text-truncate" itemprop="name">Pareja Del Año</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/myke-towers" itemprop="url"><span itemprop="name">Myke Towers,  </span></a> <a href="/artist-detail/sebastian-yatra" itemprop="url"><span itemprop="name">Sebastián Yatra</span></a></div>,
#  <div class="text-truncate" itemprop="name">Fiel</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/jhay-cortez" itemprop="url"><span itemprop="name">Jhay Cortez, </span></a> <a href="/artist-detail/los-legendarios1" itemprop="url"><span itemprop="name">Los Legendarios, </span></a> <a href="/artist-detail/wisin" itemprop="url"><span itemprop="name">Wisin</span></a></div>,
#  <div class="text-truncate" itemprop="name">Flamenco y Bachata</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/daviles-de-novelda" itemprop="url"><span itemprop="name">Daviles de Novelda</span></a></div>,
#  <div class="text-truncate" itemprop="name">AM</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/flow-la-movie" itemprop="url"><span itemprop="name">Flow La Movie, </span></a> <a href="/artist-detail/nio-garcia" itemprop="url"><span itemprop="name">Nio García</span></a></div>,
#  <div class="text-truncate" itemprop="name">Búmeran</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/beluga1" itemprop="url"><span itemprop="name">Beluga</span></a></div>,
#  <div class="text-truncate" itemprop="name">911</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/sech" itemprop="url"><span itemprop="name">Sech</span></a></div>,
#  <div class="text-truncate" itemprop="name">EL MAKINON</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/karol-g" itemprop="url"><span itemprop="name">KAROL G</span></a></div>,
#  <div class="text-truncate" itemprop="name">Snow Tha Product: Bzrp Music Sessions, Vol. 39</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/bizarrap" itemprop="url"><span itemprop="name">Bizarrap, </span></a> <a href="/artist-detail/snow-tha-product" itemprop="url"><span itemprop="name">Snow Tha Product</span></a></div>,
#  <div class="text-truncate" itemprop="name">Tú Me Dejaste de Querer (feat. Niño de Elche &amp; La Húngara)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/c-tangana" itemprop="url"><span itemprop="name">C. Tangana</span></a></div>,
#  <div class="text-truncate" itemprop="name">Solo</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/ana-mena" itemprop="url"><span itemprop="name">Ana Mena, </span></a> <a href="/artist-detail/omar-montes2" itemprop="url"><span itemprop="name">Omar Montes, </span></a> <a href="/artist-detail/maffio" itemprop="url"><span itemprop="name">Maffio</span></a></div>,
#  <div class="text-truncate" itemprop="name">Bandido</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/myke-towers" itemprop="url"><span itemprop="name">Myke Towers, </span></a> <a href="/artist-detail/juhn" itemprop="url"><span itemprop="name">Juhn</span></a></div>,
#  <div class="text-truncate" itemprop="name">Me Fijé</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/rauw-alejandro" itemprop="url"><span itemprop="name">Rauw Alejandro, </span></a> <a href="/artist-detail/alex-rose" itemprop="url"><span itemprop="name">Alex Rose</span></a></div>,
#  <div class="text-truncate" itemprop="name">Aloha (feat. Darell, Mambo Kingz &amp; DJ Luian)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/beele" itemprop="url"><span itemprop="name">Beele, </span></a> <a href="/artist-detail/rauw-alejandro" itemprop="url"><span itemprop="name">Rauw Alejandro, </span></a> <a href="/artist-detail/maluma" itemprop="url"><span itemprop="name">Maluma</span></a></div>,
#  <div class="text-truncate" itemprop="name">Ram Pam Pam</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/natti-natasha" itemprop="url"><span itemprop="name">Natti Natasha, </span></a> <a href="/artist-detail/becky-g" itemprop="url"><span itemprop="name">Becky G.</span></a></div>,
#  <div class="text-truncate" itemprop="name">Ella No Es Tuya (Remix)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/rochy-rd" itemprop="url"><span itemprop="name">Rochy RD, </span></a> <a href="/artist-detail/nicki-nicole" itemprop="url"><span itemprop="name">NICKI NICOLE, </span></a> <a href="/artist-detail/myke-towers" itemprop="url"><span itemprop="name">Myke Towers</span></a></div>,
#  <div class="text-truncate" itemprop="name">Juramento eterno de sal</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/alvaro-de-luna" itemprop="url"><span itemprop="name">Alvaro De Luna</span></a></div>,
#  <div class="text-truncate" itemprop="name">The Four Horsemen</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/aphrodites-child" itemprop="url"><span itemprop="name">Aphrodite's Child</span></a></div>,
#  <div class="text-truncate" itemprop="name">Location</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/j-balvin" itemprop="url"><span itemprop="name">J Balvin, </span></a> <a href="/artist-detail/karol-g" itemprop="url"><span itemprop="name">KAROL G, </span></a> <a href="/artist-detail/anuel-aa" itemprop="url"><span itemprop="name">Anuel AA</span></a></div>,
#  <div class="text-truncate" itemprop="name">MONTERO (Call Me By Your Name)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/lil-nas-x" itemprop="url"><span itemprop="name">Lil Nas X</span></a></div>,
#  <div class="text-truncate" itemprop="name">2/Catorce</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/mr-naisgai" itemprop="url"><span itemprop="name">Mr. Naisgai, </span></a> <a href="/artist-detail/rauw-alejandro" itemprop="url"><span itemprop="name">Rauw Alejandro</span></a></div>,
#  <div class="text-truncate" itemprop="name">Ni Una Más</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/aitana" itemprop="url"><span itemprop="name">Aitana</span></a></div>,
#  <div class="text-truncate" itemprop="name">LA NOCHE DE ANOCHE</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/rosalia" itemprop="url"><span itemprop="name">ROSALÍA, </span></a> <a href="/artist-detail/bad-bunny" itemprop="url"><span itemprop="name">Bad Bunny</span></a></div>,
#  <div class="text-truncate" itemprop="name">Through the Roof</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/oscar-carl-soderberg" itemprop="url"><span itemprop="name">Oscar Carl Soderberg</span></a></div>,
#  <div class="text-truncate" itemprop="name">Peaches (feat. Daniel Caesar &amp; GIVĒON)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/justin-bieber" itemprop="url"><span itemprop="name">Justin Bieber</span></a></div>,
#  <div class="text-truncate" itemprop="name">Friday (feat. Mufasa &amp; Hypeman) [Dopamine Re-Edit]</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/nightcrawlers" itemprop="url"><span itemprop="name">Nightcrawlers, </span></a> <a href="/artist-detail/riton" itemprop="url"><span itemprop="name">Riton</span></a></div>,
#  <div class="text-truncate" itemprop="name">512</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/jhay-cortez" itemprop="url"><span itemprop="name">Jhay Cortez, </span></a> <a href="/artist-detail/mora" itemprop="url"><span itemprop="name">Mora</span></a></div>,
#  <div class="text-truncate" itemprop="name">PIN PIN</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/myke-towers" itemprop="url"><span itemprop="name">Myke Towers</span></a></div>,
#  <div class="text-truncate" itemprop="name">The Little Giant</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/sebastian-arno-sprenger" itemprop="url"><span itemprop="name">Sebastian Arno Sprenger</span></a></div>,
#  <div class="text-truncate" itemprop="name">Dakiti</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/jhay-cortez" itemprop="url"><span itemprop="name">Jhay Cortez, </span></a> <a href="/artist-detail/bad-bunny" itemprop="url"><span itemprop="name">Bad Bunny</span></a></div>,
#  <div class="text-truncate" itemprop="name">La Historia</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/el-taiger" itemprop="url"><span itemprop="name">El Taiger, </span></a> <a href="/artist-detail/dj-conds" itemprop="url"><span itemprop="name">Dj Conds</span></a></div>,
#  <div class="text-truncate" itemprop="name">Travesuras (feat. Wisin &amp; Yandel, Myke Towers &amp; Flow La Movie) [Remix]</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/ozuna" itemprop="url"><span itemprop="name">Ozuna, </span></a> <a href="/artist-detail/casper-magico" itemprop="url"><span itemprop="name">Casper Mágico, </span></a> <a href="/artist-detail/nio-garcia" itemprop="url"><span itemprop="name">Nio García</span></a></div>,
#  <div class="text-truncate" itemprop="name">Sevilla Mundial</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/jose-nieto" itemprop="url"><span itemprop="name">José Nieto</span></a></div>,
#  <div class="text-truncate" itemprop="name">Vida de Rico</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/camilo" itemprop="url"><span itemprop="name">Camilo</span></a></div>,
#  <div class="text-truncate" itemprop="name">Turandot: Nessun doma!</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/orchestra-da-camera-di-bologna" itemprop="url"><span itemprop="name">Orchestra Da Camera Di Bologna, </span></a> <a href="/artist-detail/leone-magiera" itemprop="url"><span itemprop="name">Leone Magiera, </span></a> <a href="/artist-detail/luciano-pavarotti" itemprop="url"><span itemprop="name">Luciano Pavarotti</span></a></div>,
#  <div class="text-truncate" itemprop="name">Millones</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/camilo" itemprop="url"><span itemprop="name">Camilo</span></a></div>,
#  <div class="text-truncate" itemprop="name">Ingobernable</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/tonino-baliardo" itemprop="url"><span itemprop="name">Tonino Baliardo, </span></a> <a href="/artist-detail/c-tangana" itemprop="url"><span itemprop="name">C. Tangana, </span></a> <a href="/artist-detail/gipsy-kings" itemprop="url"><span itemprop="name">Gipsy Kings, </span></a> <a href="/artist-detail/nicolas-reyes" itemprop="url"><span itemprop="name">Nicolas Reyes</span></a></div>,
#  <div class="text-truncate" itemprop="name">Las Nenas (feat. La Duraca)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/farina1" itemprop="url"><span itemprop="name">Farina, </span></a> <a href="/artist-detail/natti-natasha" itemprop="url"><span itemprop="name">Natti Natasha, </span></a> <a href="/artist-detail/cazzu" itemprop="url"><span itemprop="name">Cazzu</span></a></div>,
#  <div class="text-truncate" itemprop="name">The Ecstasy of Gold from "The Good the Bad and the Ugly"</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/yasuto-tanaka" itemprop="url"><span itemprop="name">Yasuto Tanaka</span></a></div>,
#  <div class="text-truncate" itemprop="name">Baila Conmigo</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/selena-gomez" itemprop="url"><span itemprop="name">Selena Gomez, </span></a> <a href="/artist-detail/rauw-alejandro" itemprop="url"><span itemprop="name">Rauw Alejandro</span></a></div>,
#  <div class="text-truncate" itemprop="name">Vaudeville</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/paul-bonneau" itemprop="url"><span itemprop="name">Paul Bonneau</span></a></div>,
#  <div class="text-truncate" itemprop="name">Save Your Tears (Remix)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/the-weeknd" itemprop="url"><span itemprop="name">The Weeknd, </span></a> <a href="/artist-detail/ariana-grande" itemprop="url"><span itemprop="name">Ariana Grande</span></a></div>,
#  <div class="text-truncate" itemprop="name">MÍRENME AHORA</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/myke-towers" itemprop="url"><span itemprop="name">Myke Towers</span></a></div>,
#  <div class="text-truncate" itemprop="name">Ra, Ra, Ra</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/benito-moreno" itemprop="url"><span itemprop="name">Benito Moreno</span></a></div>,
#  <div class="text-truncate" itemprop="name">No me lo creo</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/nyno-vargas" itemprop="url"><span itemprop="name">Nyno Vargas</span></a></div>,
#  <div class="text-truncate" itemprop="name">Amor en Coma</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/manuel-turizo" itemprop="url"><span itemprop="name">Manuel Turizo, </span></a> <a href="/artist-detail/maluma" itemprop="url"><span itemprop="name">Maluma</span></a></div>,
#  <div class="text-truncate" itemprop="name">Sal y Perrea</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/sech" itemprop="url"><span itemprop="name">Sech</span></a></div>,
#  <div class="text-truncate" itemprop="name">Wao</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/sech" itemprop="url"><span itemprop="name">Sech</span></a></div>,
#  <div class="text-truncate" itemprop="name">Northwest Wind</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/hans-johnson" itemprop="url"><span itemprop="name">Hans Johnson</span></a></div>,
#  <div class="text-truncate" itemprop="name">La Curiosidad</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/nesty3" itemprop="url"><span itemprop="name">Nesty</span></a></div>,
#  <div class="text-truncate" itemprop="name">KESI</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/camilo" itemprop="url"><span itemprop="name">Camilo</span></a></div>,
#  <div class="text-truncate" itemprop="name">El Partidazo (COPE)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/huecco" itemprop="url"><span itemprop="name">Huecco</span></a></div>,
#  <div class="text-truncate" itemprop="name">Real Apps</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/peter-jeremias" itemprop="url"><span itemprop="name">Peter Jeremias</span></a></div>,
#  <div class="text-truncate" itemprop="name">Vida de Rico</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/la-novel-de-martin-guevara" itemprop="url"><span itemprop="name">La Novel de Martín Guevara</span></a></div>,
#  <div class="text-truncate" itemprop="name">Bringing the Happy</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/david-cleveland" itemprop="url"><span itemprop="name">David Cleveland, </span></a> <a href="/artist-detail/tom-snider" itemprop="url"><span itemprop="name">Tom Snider</span></a></div>,
#  <div class="text-truncate" itemprop="name">L-Gante: Bzrp Music Sessions, Vol.38</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/l-gante" itemprop="url"><span itemprop="name">L-Gante, </span></a> <a href="/artist-detail/bizarrap" itemprop="url"><span itemprop="name">Bizarrap</span></a></div>,
#  <div class="text-truncate" itemprop="name">Sudores fríos</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/recycled-j1" itemprop="url"><span itemprop="name">Recycled J, </span></a> <a href="/artist-detail/natos-y-waor" itemprop="url"><span itemprop="name">Natos y Waor</span></a></div>,
#  <div class="text-truncate" itemprop="name">Your Power</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/billie-eilish" itemprop="url"><span itemprop="name">Billie Eilish</span></a></div>,
#  <div class="text-truncate" itemprop="name">Levitating (feat. DaBaby)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/dua-lipa" itemprop="url"><span itemprop="name">Dua Lipa</span></a></div>,
#  <div class="text-truncate" itemprop="name">Hopeful Road</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/inspired-music" itemprop="url"><span itemprop="name">Inspired Music</span></a></div>,
#  <div class="text-truncate" itemprop="name">De Pies a Cabeza</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/pedro-infante" itemprop="url"><span itemprop="name">Pedro Infante</span></a></div>,
#  <div class="text-truncate" itemprop="name">Fellini's Stories</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/fabio-di-bari" itemprop="url"><span itemprop="name">Fabio Di Bari, </span></a> <a href="/artist-detail/giulio-vetrone" itemprop="url"><span itemprop="name">Giulio Vetrone, </span></a> <a href="/artist-detail/daniele-benati" itemprop="url"><span itemprop="name">Daniele Benati</span></a></div>,
#  <div class="text-truncate" itemprop="name">Explícito</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/myke-towers" itemprop="url"><span itemprop="name">Myke Towers</span></a></div>,
#  <div class="text-truncate" itemprop="name">Vuelve, Vuelve</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/danna-paola" itemprop="url"><span itemprop="name">Danna Paola, </span></a> <a href="/artist-detail/david-bisbal" itemprop="url"><span itemprop="name">David Bisbal</span></a></div>,
#  <div class="text-truncate" itemprop="name">My Head &amp; My Heart</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/ava-max" itemprop="url"><span itemprop="name">Ava Max</span></a></div>,
#  <div class="text-truncate" itemprop="name">Machu Picchu</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/camilo" itemprop="url"><span itemprop="name">Camilo</span></a></div>,
#  <div class="text-truncate" itemprop="name">Conexión (feat. Bryant Myers, Eladio Carrión &amp; Tory Lanez)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/justin-quiles" itemprop="url"><span itemprop="name">Justin Quiles, </span></a> <a href="/artist-detail/jay-wheeler" itemprop="url"><span itemprop="name">Jay Wheeler, </span></a> <a href="/artist-detail/foreign-teck" itemprop="url"><span itemprop="name">Foreign Teck</span></a></div>,
#  <div class="text-truncate" itemprop="name">Christian Dior</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/jhay-cortez" itemprop="url"><span itemprop="name">Jhay Cortez</span></a></div>,
#  <div class="text-truncate" itemprop="name">Hypnotized</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/sophie-and-the-giants" itemprop="url"><span itemprop="name">Sophie and the Giants, </span></a> <a href="/artist-detail/purple-disco-machine" itemprop="url"><span itemprop="name">Purple Disco Machine</span></a></div>,
#  <div class="text-truncate" itemprop="name">La Nota</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/manuel-turizo" itemprop="url"><span itemprop="name">Manuel Turizo, </span></a> <a href="/artist-detail/myke-towers" itemprop="url"><span itemprop="name">Myke Towers, </span></a> <a href="/artist-detail/rauw-alejandro" itemprop="url"><span itemprop="name">Rauw Alejandro</span></a></div>,
#  <div class="text-truncate" itemprop="name">Canción Bonita</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/carlos-vives" itemprop="url"><span itemprop="name">Carlos Vives, </span></a> <a href="/artist-detail/ricky-martin" itemprop="url"><span itemprop="name">Ricky Martin</span></a></div>,
#  <div class="text-truncate" itemprop="name">Skippety Skip, Pt. 2</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/thierry-caroubi" itemprop="url"><span itemprop="name">Thierry Caroubi</span></a></div>,
#  <div class="text-truncate" itemprop="name">Decidida</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/la-xinni" itemprop="url"><span itemprop="name">La Xinni</span></a></div>,
#  <div class="text-truncate" itemprop="name">News Flash</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/warnerchappell-productions" itemprop="url"><span itemprop="name">Warner/Chappell Productions</span></a></div>,
#  <div class="text-truncate" itemprop="name">Hecha Pa' Mi</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/boza2" itemprop="url"><span itemprop="name">Boza</span></a></div>,
#  <div class="text-truncate" itemprop="name">A un passo dalla luna</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/ana-mena" itemprop="url"><span itemprop="name">Ana Mena, </span></a> <a href="/artist-detail/rocco-hunt" itemprop="url"><span itemprop="name">Rocco Hunt</span></a></div>,
#  <div class="text-truncate" itemprop="name">Rainbow Riders</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/zest-music" itemprop="url"><span itemprop="name">Zest Music</span></a></div>,
#  <div class="text-truncate" itemprop="name">La Cartita</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/rasel" itemprop="url"><span itemprop="name">Rasel, </span></a> <a href="/artist-detail/keen-levy" itemprop="url"><span itemprop="name">Keen Levy</span></a></div>,
#  <div class="text-truncate" itemprop="name">Diamonds</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/sam-smith" itemprop="url"><span itemprop="name">Sam Smith</span></a></div>,
#  <div class="text-truncate" itemprop="name">La Mamá de la Mamá (feat. El Cherry Scom)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/el-alfa" itemprop="url"><span itemprop="name">El Alfa, </span></a> <a href="/artist-detail/chael-produciendo" itemprop="url"><span itemprop="name">Chael Produciendo, </span></a> <a href="/artist-detail/cj9" itemprop="url"><span itemprop="name">CJ</span></a></div>,
#  <div class="text-truncate" itemprop="name">La promesa</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/manga-corta" itemprop="url"><span itemprop="name">Manga Corta</span></a></div>,
#  <div class="text-truncate" itemprop="name">LE GUSTA QUE LA VEAN</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/lunay" itemprop="url"><span itemprop="name">Lunay</span></a></div>,
#  <div class="text-truncate" itemprop="name">You Need To Calm Down</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/taylor-swift" itemprop="url"><span itemprop="name">Taylor Swift</span></a></div>,
#  <div class="text-truncate" itemprop="name">Big Sky</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/warnerchappell-productions" itemprop="url"><span itemprop="name">Warner/Chappell Productions</span></a></div>,
#  <div class="text-truncate" itemprop="name">Amoralí (with Potito)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/vicente-amigo" itemprop="url"><span itemprop="name">Vicente Amigo</span></a></div>,
#  <div class="text-truncate" itemprop="name">Tiroteo (Remix)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/rauw-alejandro" itemprop="url"><span itemprop="name">Rauw Alejandro, </span></a> <a href="/artist-detail/pol-granch" itemprop="url"><span itemprop="name">Pol Granch, </span></a> <a href="/artist-detail/marc-segui" itemprop="url"><span itemprop="name">Marc Segui</span></a></div>,
#  <div class="text-truncate" itemprop="name">11 RAZONES</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/aitana" itemprop="url"><span itemprop="name">Aitana</span></a></div>,
#  <div class="text-truncate" itemprop="name">Otra Noche Sin Ti</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/j-balvin" itemprop="url"><span itemprop="name">J Balvin, </span></a> <a href="/artist-detail/khalid" itemprop="url"><span itemprop="name">Khalid</span></a></div>,
#  <div class="text-truncate" itemprop="name">EL PONY</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/daddy-yankee" itemprop="url"><span itemprop="name">Daddy Yankee</span></a></div>,
#  <div class="text-truncate" itemprop="name">Beautiful Cells</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/sebastien-gulluni" itemprop="url"><span itemprop="name">Sebastien Gulluni</span></a></div>,
#  <div class="text-truncate" itemprop="name">A Un Paso De La Luna</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/ana-mena" itemprop="url"><span itemprop="name">Ana Mena, </span></a> <a href="/artist-detail/rocco-hunt" itemprop="url"><span itemprop="name">Rocco Hunt</span></a></div>,
#  <div class="text-truncate" itemprop="name">Porfa no te vayas</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/morat" itemprop="url"><span itemprop="name">Morat, </span></a> <a href="/artist-detail/beret" itemprop="url"><span itemprop="name">Beret</span></a></div>,
#  <div class="text-truncate" itemprop="name">Dynamite</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/bts" itemprop="url"><span itemprop="name">BTS</span></a></div>,
#  <div class="text-truncate" itemprop="name">Ringui Dingui (feat. SFDK)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/kaseo1" itemprop="url"><span itemprop="name">Kase.O</span></a></div>,
#  <div class="text-truncate" itemprop="name">Play Ball</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/acdc" itemprop="url"><span itemprop="name">AC/DC</span></a></div>,
#  <div class="text-truncate" itemprop="name">I Promised Myself</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/nick-kamen" itemprop="url"><span itemprop="name">Nick Kamen</span></a></div>,
#  <div class="text-truncate" itemprop="name">Kiss Me More (feat. SZA)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/doja-cat" itemprop="url"><span itemprop="name">Doja Cat</span></a></div>,
#  <div class="text-truncate" itemprop="name">Jerusalema (feat. Nomcebo Zikode) [Edit]</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/master-kg" itemprop="url"><span itemprop="name">Master KG</span></a></div>,
#  <div class="text-truncate" itemprop="name">Poblado</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/totoy-el-frio" itemprop="url"><span itemprop="name">Totoy El Frio, </span></a> <a href="/artist-detail/natan-shander" itemprop="url"><span itemprop="name">Natan &amp; Shander, </span></a> <a href="/artist-detail/crissin" itemprop="url"><span itemprop="name">Crissin</span></a></div>,
#  <div class="text-truncate" itemprop="name">Sonqueson</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/la-pegatina" itemprop="url"><span itemprop="name">La Pegatina</span></a></div>,
#  <div class="text-truncate" itemprop="name">Inside News</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/warnerchappell-productions" itemprop="url"><span itemprop="name">Warner/Chappell Productions</span></a></div>,
#  <div class="col-12 p-0 text-truncate" style="height: 20px"><a href="" id="audio-song-href"><span class="audio-song-title"></span></a></div>,
#  <div class="col-12 p-0 text-truncate"><span class="audio-song-artists">Los Legendarios, Wisin &amp; Jhay Cortez</span></div>]

# %%
soup.select("div.text-truncate")[0].get_text()
# Out:
# 'Pareja Del Año'

# %%
soup.select("#s1 > div.col-10.d-flex.align-items-center.pl-0")
# Out:
# [<div class="col-10 d-flex align-items-center pl-0"><div class="col-1 align-middle text-center info-detail-artist-numbers numbers-min-width max-width-fit p-0 ml-lg-2"><span>1</span></div><div class="col-3 marg-alb-card mr-sm-1 img-size pl-0 pr-1 px-lg-2" onclick="playSelectedSong(0)"><div class="container-img-text"><img alt="Pareja Del Año artwork" class="image-on-bar" data-src="https://is5-ssl.mzstatic.com/image/thumb/Music114/v4/ff/8b/6c/ff8b6c97-11f3-9f3f-c441-30887275da82/21UMGIM25076.rgb.jpg/60x60bb.jpeg" src="https://cdn.top-charts.com/static/images/loading.gif"/><img alt="play" class="centered song-card-play-button" id="1-img" src="https://cdn.top-charts.com/static/images/BT_Play.png"/></div></div><div class="col-8"><div class="row song-text" id="title" style=""><div class="col-12 p-0"><span class="song-text" itemprop="track" itemscope="" itemtype="http://schema.org/MusicRecording"><a href="/s/pareja-del-ano-sebastian-yatra-myke-towers" itemprop="url"><div class="text-truncate" itemprop="name">Pareja Del Año</div></a></span></div></div><div class="row artist-text text-color-sing" id="Artist"><div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/myke-towers" itemprop="url"><span itemprop="name">Myke Towers,  </span></a> <a href="/artist-detail/sebastian-yatra" itemprop="url"><span itemprop="name">Sebastián Yatra</span></a></div></div></div></div>]

# %%
soup.select("div.text-truncate")
# Out:
# [<div class="text-truncate" itemprop="name">Pareja Del Año</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/myke-towers" itemprop="url"><span itemprop="name">Myke Towers,  </span></a> <a href="/artist-detail/sebastian-yatra" itemprop="url"><span itemprop="name">Sebastián Yatra</span></a></div>,
#  <div class="text-truncate" itemprop="name">Fiel</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/jhay-cortez" itemprop="url"><span itemprop="name">Jhay Cortez, </span></a> <a href="/artist-detail/los-legendarios1" itemprop="url"><span itemprop="name">Los Legendarios, </span></a> <a href="/artist-detail/wisin" itemprop="url"><span itemprop="name">Wisin</span></a></div>,
#  <div class="text-truncate" itemprop="name">Flamenco y Bachata</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/daviles-de-novelda" itemprop="url"><span itemprop="name">Daviles de Novelda</span></a></div>,
#  <div class="text-truncate" itemprop="name">AM</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/flow-la-movie" itemprop="url"><span itemprop="name">Flow La Movie, </span></a> <a href="/artist-detail/nio-garcia" itemprop="url"><span itemprop="name">Nio García</span></a></div>,
#  <div class="text-truncate" itemprop="name">Búmeran</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/beluga1" itemprop="url"><span itemprop="name">Beluga</span></a></div>,
#  <div class="text-truncate" itemprop="name">911</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/sech" itemprop="url"><span itemprop="name">Sech</span></a></div>,
#  <div class="text-truncate" itemprop="name">EL MAKINON</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/karol-g" itemprop="url"><span itemprop="name">KAROL G</span></a></div>,
#  <div class="text-truncate" itemprop="name">Snow Tha Product: Bzrp Music Sessions, Vol. 39</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/bizarrap" itemprop="url"><span itemprop="name">Bizarrap, </span></a> <a href="/artist-detail/snow-tha-product" itemprop="url"><span itemprop="name">Snow Tha Product</span></a></div>,
#  <div class="text-truncate" itemprop="name">Tú Me Dejaste de Querer (feat. Niño de Elche &amp; La Húngara)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/c-tangana" itemprop="url"><span itemprop="name">C. Tangana</span></a></div>,
#  <div class="text-truncate" itemprop="name">Solo</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/ana-mena" itemprop="url"><span itemprop="name">Ana Mena, </span></a> <a href="/artist-detail/omar-montes2" itemprop="url"><span itemprop="name">Omar Montes, </span></a> <a href="/artist-detail/maffio" itemprop="url"><span itemprop="name">Maffio</span></a></div>,
#  <div class="text-truncate" itemprop="name">Bandido</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/myke-towers" itemprop="url"><span itemprop="name">Myke Towers, </span></a> <a href="/artist-detail/juhn" itemprop="url"><span itemprop="name">Juhn</span></a></div>,
#  <div class="text-truncate" itemprop="name">Me Fijé</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/rauw-alejandro" itemprop="url"><span itemprop="name">Rauw Alejandro, </span></a> <a href="/artist-detail/alex-rose" itemprop="url"><span itemprop="name">Alex Rose</span></a></div>,
#  <div class="text-truncate" itemprop="name">Aloha (feat. Darell, Mambo Kingz &amp; DJ Luian)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/beele" itemprop="url"><span itemprop="name">Beele, </span></a> <a href="/artist-detail/rauw-alejandro" itemprop="url"><span itemprop="name">Rauw Alejandro, </span></a> <a href="/artist-detail/maluma" itemprop="url"><span itemprop="name">Maluma</span></a></div>,
#  <div class="text-truncate" itemprop="name">Ram Pam Pam</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/natti-natasha" itemprop="url"><span itemprop="name">Natti Natasha, </span></a> <a href="/artist-detail/becky-g" itemprop="url"><span itemprop="name">Becky G.</span></a></div>,
#  <div class="text-truncate" itemprop="name">Ella No Es Tuya (Remix)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/rochy-rd" itemprop="url"><span itemprop="name">Rochy RD, </span></a> <a href="/artist-detail/nicki-nicole" itemprop="url"><span itemprop="name">NICKI NICOLE, </span></a> <a href="/artist-detail/myke-towers" itemprop="url"><span itemprop="name">Myke Towers</span></a></div>,
#  <div class="text-truncate" itemprop="name">Juramento eterno de sal</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/alvaro-de-luna" itemprop="url"><span itemprop="name">Alvaro De Luna</span></a></div>,
#  <div class="text-truncate" itemprop="name">The Four Horsemen</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/aphrodites-child" itemprop="url"><span itemprop="name">Aphrodite's Child</span></a></div>,
#  <div class="text-truncate" itemprop="name">Location</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/j-balvin" itemprop="url"><span itemprop="name">J Balvin, </span></a> <a href="/artist-detail/karol-g" itemprop="url"><span itemprop="name">KAROL G, </span></a> <a href="/artist-detail/anuel-aa" itemprop="url"><span itemprop="name">Anuel AA</span></a></div>,
#  <div class="text-truncate" itemprop="name">MONTERO (Call Me By Your Name)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/lil-nas-x" itemprop="url"><span itemprop="name">Lil Nas X</span></a></div>,
#  <div class="text-truncate" itemprop="name">2/Catorce</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/mr-naisgai" itemprop="url"><span itemprop="name">Mr. Naisgai, </span></a> <a href="/artist-detail/rauw-alejandro" itemprop="url"><span itemprop="name">Rauw Alejandro</span></a></div>,
#  <div class="text-truncate" itemprop="name">Ni Una Más</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/aitana" itemprop="url"><span itemprop="name">Aitana</span></a></div>,
#  <div class="text-truncate" itemprop="name">LA NOCHE DE ANOCHE</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/rosalia" itemprop="url"><span itemprop="name">ROSALÍA, </span></a> <a href="/artist-detail/bad-bunny" itemprop="url"><span itemprop="name">Bad Bunny</span></a></div>,
#  <div class="text-truncate" itemprop="name">Through the Roof</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/oscar-carl-soderberg" itemprop="url"><span itemprop="name">Oscar Carl Soderberg</span></a></div>,
#  <div class="text-truncate" itemprop="name">Peaches (feat. Daniel Caesar &amp; GIVĒON)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/justin-bieber" itemprop="url"><span itemprop="name">Justin Bieber</span></a></div>,
#  <div class="text-truncate" itemprop="name">Friday (feat. Mufasa &amp; Hypeman) [Dopamine Re-Edit]</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/nightcrawlers" itemprop="url"><span itemprop="name">Nightcrawlers, </span></a> <a href="/artist-detail/riton" itemprop="url"><span itemprop="name">Riton</span></a></div>,
#  <div class="text-truncate" itemprop="name">512</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/jhay-cortez" itemprop="url"><span itemprop="name">Jhay Cortez, </span></a> <a href="/artist-detail/mora" itemprop="url"><span itemprop="name">Mora</span></a></div>,
#  <div class="text-truncate" itemprop="name">PIN PIN</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/myke-towers" itemprop="url"><span itemprop="name">Myke Towers</span></a></div>,
#  <div class="text-truncate" itemprop="name">The Little Giant</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/sebastian-arno-sprenger" itemprop="url"><span itemprop="name">Sebastian Arno Sprenger</span></a></div>,
#  <div class="text-truncate" itemprop="name">Dakiti</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/jhay-cortez" itemprop="url"><span itemprop="name">Jhay Cortez, </span></a> <a href="/artist-detail/bad-bunny" itemprop="url"><span itemprop="name">Bad Bunny</span></a></div>,
#  <div class="text-truncate" itemprop="name">La Historia</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/el-taiger" itemprop="url"><span itemprop="name">El Taiger, </span></a> <a href="/artist-detail/dj-conds" itemprop="url"><span itemprop="name">Dj Conds</span></a></div>,
#  <div class="text-truncate" itemprop="name">Travesuras (feat. Wisin &amp; Yandel, Myke Towers &amp; Flow La Movie) [Remix]</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/ozuna" itemprop="url"><span itemprop="name">Ozuna, </span></a> <a href="/artist-detail/casper-magico" itemprop="url"><span itemprop="name">Casper Mágico, </span></a> <a href="/artist-detail/nio-garcia" itemprop="url"><span itemprop="name">Nio García</span></a></div>,
#  <div class="text-truncate" itemprop="name">Sevilla Mundial</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/jose-nieto" itemprop="url"><span itemprop="name">José Nieto</span></a></div>,
#  <div class="text-truncate" itemprop="name">Vida de Rico</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/camilo" itemprop="url"><span itemprop="name">Camilo</span></a></div>,
#  <div class="text-truncate" itemprop="name">Turandot: Nessun doma!</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/orchestra-da-camera-di-bologna" itemprop="url"><span itemprop="name">Orchestra Da Camera Di Bologna, </span></a> <a href="/artist-detail/leone-magiera" itemprop="url"><span itemprop="name">Leone Magiera, </span></a> <a href="/artist-detail/luciano-pavarotti" itemprop="url"><span itemprop="name">Luciano Pavarotti</span></a></div>,
#  <div class="text-truncate" itemprop="name">Millones</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/camilo" itemprop="url"><span itemprop="name">Camilo</span></a></div>,
#  <div class="text-truncate" itemprop="name">Ingobernable</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/tonino-baliardo" itemprop="url"><span itemprop="name">Tonino Baliardo, </span></a> <a href="/artist-detail/c-tangana" itemprop="url"><span itemprop="name">C. Tangana, </span></a> <a href="/artist-detail/gipsy-kings" itemprop="url"><span itemprop="name">Gipsy Kings, </span></a> <a href="/artist-detail/nicolas-reyes" itemprop="url"><span itemprop="name">Nicolas Reyes</span></a></div>,
#  <div class="text-truncate" itemprop="name">Las Nenas (feat. La Duraca)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/farina1" itemprop="url"><span itemprop="name">Farina, </span></a> <a href="/artist-detail/natti-natasha" itemprop="url"><span itemprop="name">Natti Natasha, </span></a> <a href="/artist-detail/cazzu" itemprop="url"><span itemprop="name">Cazzu</span></a></div>,
#  <div class="text-truncate" itemprop="name">The Ecstasy of Gold from "The Good the Bad and the Ugly"</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/yasuto-tanaka" itemprop="url"><span itemprop="name">Yasuto Tanaka</span></a></div>,
#  <div class="text-truncate" itemprop="name">Baila Conmigo</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/selena-gomez" itemprop="url"><span itemprop="name">Selena Gomez, </span></a> <a href="/artist-detail/rauw-alejandro" itemprop="url"><span itemprop="name">Rauw Alejandro</span></a></div>,
#  <div class="text-truncate" itemprop="name">Vaudeville</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/paul-bonneau" itemprop="url"><span itemprop="name">Paul Bonneau</span></a></div>,
#  <div class="text-truncate" itemprop="name">Save Your Tears (Remix)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/the-weeknd" itemprop="url"><span itemprop="name">The Weeknd, </span></a> <a href="/artist-detail/ariana-grande" itemprop="url"><span itemprop="name">Ariana Grande</span></a></div>,
#  <div class="text-truncate" itemprop="name">MÍRENME AHORA</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/myke-towers" itemprop="url"><span itemprop="name">Myke Towers</span></a></div>,
#  <div class="text-truncate" itemprop="name">Ra, Ra, Ra</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/benito-moreno" itemprop="url"><span itemprop="name">Benito Moreno</span></a></div>,
#  <div class="text-truncate" itemprop="name">No me lo creo</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/nyno-vargas" itemprop="url"><span itemprop="name">Nyno Vargas</span></a></div>,
#  <div class="text-truncate" itemprop="name">Amor en Coma</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/manuel-turizo" itemprop="url"><span itemprop="name">Manuel Turizo, </span></a> <a href="/artist-detail/maluma" itemprop="url"><span itemprop="name">Maluma</span></a></div>,
#  <div class="text-truncate" itemprop="name">Sal y Perrea</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/sech" itemprop="url"><span itemprop="name">Sech</span></a></div>,
#  <div class="text-truncate" itemprop="name">Wao</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/sech" itemprop="url"><span itemprop="name">Sech</span></a></div>,
#  <div class="text-truncate" itemprop="name">Northwest Wind</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/hans-johnson" itemprop="url"><span itemprop="name">Hans Johnson</span></a></div>,
#  <div class="text-truncate" itemprop="name">La Curiosidad</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/nesty3" itemprop="url"><span itemprop="name">Nesty</span></a></div>,
#  <div class="text-truncate" itemprop="name">KESI</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/camilo" itemprop="url"><span itemprop="name">Camilo</span></a></div>,
#  <div class="text-truncate" itemprop="name">El Partidazo (COPE)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/huecco" itemprop="url"><span itemprop="name">Huecco</span></a></div>,
#  <div class="text-truncate" itemprop="name">Real Apps</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/peter-jeremias" itemprop="url"><span itemprop="name">Peter Jeremias</span></a></div>,
#  <div class="text-truncate" itemprop="name">Vida de Rico</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/la-novel-de-martin-guevara" itemprop="url"><span itemprop="name">La Novel de Martín Guevara</span></a></div>,
#  <div class="text-truncate" itemprop="name">Bringing the Happy</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/david-cleveland" itemprop="url"><span itemprop="name">David Cleveland, </span></a> <a href="/artist-detail/tom-snider" itemprop="url"><span itemprop="name">Tom Snider</span></a></div>,
#  <div class="text-truncate" itemprop="name">L-Gante: Bzrp Music Sessions, Vol.38</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/l-gante" itemprop="url"><span itemprop="name">L-Gante, </span></a> <a href="/artist-detail/bizarrap" itemprop="url"><span itemprop="name">Bizarrap</span></a></div>,
#  <div class="text-truncate" itemprop="name">Sudores fríos</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/recycled-j1" itemprop="url"><span itemprop="name">Recycled J, </span></a> <a href="/artist-detail/natos-y-waor" itemprop="url"><span itemprop="name">Natos y Waor</span></a></div>,
#  <div class="text-truncate" itemprop="name">Your Power</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/billie-eilish" itemprop="url"><span itemprop="name">Billie Eilish</span></a></div>,
#  <div class="text-truncate" itemprop="name">Levitating (feat. DaBaby)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/dua-lipa" itemprop="url"><span itemprop="name">Dua Lipa</span></a></div>,
#  <div class="text-truncate" itemprop="name">Hopeful Road</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/inspired-music" itemprop="url"><span itemprop="name">Inspired Music</span></a></div>,
#  <div class="text-truncate" itemprop="name">De Pies a Cabeza</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/pedro-infante" itemprop="url"><span itemprop="name">Pedro Infante</span></a></div>,
#  <div class="text-truncate" itemprop="name">Fellini's Stories</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/fabio-di-bari" itemprop="url"><span itemprop="name">Fabio Di Bari, </span></a> <a href="/artist-detail/giulio-vetrone" itemprop="url"><span itemprop="name">Giulio Vetrone, </span></a> <a href="/artist-detail/daniele-benati" itemprop="url"><span itemprop="name">Daniele Benati</span></a></div>,
#  <div class="text-truncate" itemprop="name">Explícito</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/myke-towers" itemprop="url"><span itemprop="name">Myke Towers</span></a></div>,
#  <div class="text-truncate" itemprop="name">Vuelve, Vuelve</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/danna-paola" itemprop="url"><span itemprop="name">Danna Paola, </span></a> <a href="/artist-detail/david-bisbal" itemprop="url"><span itemprop="name">David Bisbal</span></a></div>,
#  <div class="text-truncate" itemprop="name">My Head &amp; My Heart</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/ava-max" itemprop="url"><span itemprop="name">Ava Max</span></a></div>,
#  <div class="text-truncate" itemprop="name">Machu Picchu</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/camilo" itemprop="url"><span itemprop="name">Camilo</span></a></div>,
#  <div class="text-truncate" itemprop="name">Conexión (feat. Bryant Myers, Eladio Carrión &amp; Tory Lanez)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/justin-quiles" itemprop="url"><span itemprop="name">Justin Quiles, </span></a> <a href="/artist-detail/jay-wheeler" itemprop="url"><span itemprop="name">Jay Wheeler, </span></a> <a href="/artist-detail/foreign-teck" itemprop="url"><span itemprop="name">Foreign Teck</span></a></div>,
#  <div class="text-truncate" itemprop="name">Christian Dior</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/jhay-cortez" itemprop="url"><span itemprop="name">Jhay Cortez</span></a></div>,
#  <div class="text-truncate" itemprop="name">Hypnotized</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/sophie-and-the-giants" itemprop="url"><span itemprop="name">Sophie and the Giants, </span></a> <a href="/artist-detail/purple-disco-machine" itemprop="url"><span itemprop="name">Purple Disco Machine</span></a></div>,
#  <div class="text-truncate" itemprop="name">La Nota</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/manuel-turizo" itemprop="url"><span itemprop="name">Manuel Turizo, </span></a> <a href="/artist-detail/myke-towers" itemprop="url"><span itemprop="name">Myke Towers, </span></a> <a href="/artist-detail/rauw-alejandro" itemprop="url"><span itemprop="name">Rauw Alejandro</span></a></div>,
#  <div class="text-truncate" itemprop="name">Canción Bonita</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/carlos-vives" itemprop="url"><span itemprop="name">Carlos Vives, </span></a> <a href="/artist-detail/ricky-martin" itemprop="url"><span itemprop="name">Ricky Martin</span></a></div>,
#  <div class="text-truncate" itemprop="name">Skippety Skip, Pt. 2</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/thierry-caroubi" itemprop="url"><span itemprop="name">Thierry Caroubi</span></a></div>,
#  <div class="text-truncate" itemprop="name">Decidida</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/la-xinni" itemprop="url"><span itemprop="name">La Xinni</span></a></div>,
#  <div class="text-truncate" itemprop="name">News Flash</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/warnerchappell-productions" itemprop="url"><span itemprop="name">Warner/Chappell Productions</span></a></div>,
#  <div class="text-truncate" itemprop="name">Hecha Pa' Mi</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/boza2" itemprop="url"><span itemprop="name">Boza</span></a></div>,
#  <div class="text-truncate" itemprop="name">A un passo dalla luna</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/ana-mena" itemprop="url"><span itemprop="name">Ana Mena, </span></a> <a href="/artist-detail/rocco-hunt" itemprop="url"><span itemprop="name">Rocco Hunt</span></a></div>,
#  <div class="text-truncate" itemprop="name">Rainbow Riders</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/zest-music" itemprop="url"><span itemprop="name">Zest Music</span></a></div>,
#  <div class="text-truncate" itemprop="name">La Cartita</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/rasel" itemprop="url"><span itemprop="name">Rasel, </span></a> <a href="/artist-detail/keen-levy" itemprop="url"><span itemprop="name">Keen Levy</span></a></div>,
#  <div class="text-truncate" itemprop="name">Diamonds</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/sam-smith" itemprop="url"><span itemprop="name">Sam Smith</span></a></div>,
#  <div class="text-truncate" itemprop="name">La Mamá de la Mamá (feat. El Cherry Scom)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/el-alfa" itemprop="url"><span itemprop="name">El Alfa, </span></a> <a href="/artist-detail/chael-produciendo" itemprop="url"><span itemprop="name">Chael Produciendo, </span></a> <a href="/artist-detail/cj9" itemprop="url"><span itemprop="name">CJ</span></a></div>,
#  <div class="text-truncate" itemprop="name">La promesa</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/manga-corta" itemprop="url"><span itemprop="name">Manga Corta</span></a></div>,
#  <div class="text-truncate" itemprop="name">LE GUSTA QUE LA VEAN</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/lunay" itemprop="url"><span itemprop="name">Lunay</span></a></div>,
#  <div class="text-truncate" itemprop="name">You Need To Calm Down</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/taylor-swift" itemprop="url"><span itemprop="name">Taylor Swift</span></a></div>,
#  <div class="text-truncate" itemprop="name">Big Sky</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/warnerchappell-productions" itemprop="url"><span itemprop="name">Warner/Chappell Productions</span></a></div>,
#  <div class="text-truncate" itemprop="name">Amoralí (with Potito)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/vicente-amigo" itemprop="url"><span itemprop="name">Vicente Amigo</span></a></div>,
#  <div class="text-truncate" itemprop="name">Tiroteo (Remix)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/rauw-alejandro" itemprop="url"><span itemprop="name">Rauw Alejandro, </span></a> <a href="/artist-detail/pol-granch" itemprop="url"><span itemprop="name">Pol Granch, </span></a> <a href="/artist-detail/marc-segui" itemprop="url"><span itemprop="name">Marc Segui</span></a></div>,
#  <div class="text-truncate" itemprop="name">11 RAZONES</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/aitana" itemprop="url"><span itemprop="name">Aitana</span></a></div>,
#  <div class="text-truncate" itemprop="name">Otra Noche Sin Ti</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/j-balvin" itemprop="url"><span itemprop="name">J Balvin, </span></a> <a href="/artist-detail/khalid" itemprop="url"><span itemprop="name">Khalid</span></a></div>,
#  <div class="text-truncate" itemprop="name">EL PONY</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/daddy-yankee" itemprop="url"><span itemprop="name">Daddy Yankee</span></a></div>,
#  <div class="text-truncate" itemprop="name">Beautiful Cells</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/sebastien-gulluni" itemprop="url"><span itemprop="name">Sebastien Gulluni</span></a></div>,
#  <div class="text-truncate" itemprop="name">A Un Paso De La Luna</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/ana-mena" itemprop="url"><span itemprop="name">Ana Mena, </span></a> <a href="/artist-detail/rocco-hunt" itemprop="url"><span itemprop="name">Rocco Hunt</span></a></div>,
#  <div class="text-truncate" itemprop="name">Porfa no te vayas</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/morat" itemprop="url"><span itemprop="name">Morat, </span></a> <a href="/artist-detail/beret" itemprop="url"><span itemprop="name">Beret</span></a></div>,
#  <div class="text-truncate" itemprop="name">Dynamite</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/bts" itemprop="url"><span itemprop="name">BTS</span></a></div>,
#  <div class="text-truncate" itemprop="name">Ringui Dingui (feat. SFDK)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/kaseo1" itemprop="url"><span itemprop="name">Kase.O</span></a></div>,
#  <div class="text-truncate" itemprop="name">Play Ball</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/acdc" itemprop="url"><span itemprop="name">AC/DC</span></a></div>,
#  <div class="text-truncate" itemprop="name">I Promised Myself</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/nick-kamen" itemprop="url"><span itemprop="name">Nick Kamen</span></a></div>,
#  <div class="text-truncate" itemprop="name">Kiss Me More (feat. SZA)</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/doja-cat" itemprop="url"><span itemprop="name">Doja Cat</span></a></div>,
#  <div class="text-truncate" itemprop="name">Jerusalema (feat. Nomcebo Zikode) [Edit]</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/master-kg" itemprop="url"><span itemprop="name">Master KG</span></a></div>,
#  <div class="text-truncate" itemprop="name">Poblado</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/totoy-el-frio" itemprop="url"><span itemprop="name">Totoy El Frio, </span></a> <a href="/artist-detail/natan-shander" itemprop="url"><span itemprop="name">Natan &amp; Shander, </span></a> <a href="/artist-detail/crissin" itemprop="url"><span itemprop="name">Crissin</span></a></div>,
#  <div class="text-truncate" itemprop="name">Sonqueson</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/la-pegatina" itemprop="url"><span itemprop="name">La Pegatina</span></a></div>,
#  <div class="text-truncate" itemprop="name">Inside News</div>,
#  <div class="col-12 p-0 text-truncate d-block"><a href="/artist-detail/warnerchappell-productions" itemprop="url"><span itemprop="name">Warner/Chappell Productions</span></a></div>,
#  <div class="col-12 p-0 text-truncate" style="height: 20px"><a href="" id="audio-song-href"><span class="audio-song-title"></span></a></div>,
#  <div class="col-12 p-0 text-truncate"><span class="audio-song-artists">Los Legendarios, Wisin &amp; Jhay Cortez</span></div>]

# %%
soup.select("div.text-truncate")[0].get_text()
# Out:
# 'Pareja Del Año'

# %%
title = []
artist = []
num_iter = len(soup.select("div.text-truncate"))

for i in range(num_iter):
    if i% 2 == 0:
        title.append(soup.select("div.text-truncate")[i].get_text())
    else:
        artist.append(soup.select("div.text-truncate")[i].get_text())

# %%
topspain = pd.DataFrame({"title":title,"artist":artist})

# %%
topspain
# Out:
#                                         title  \
# 0                              Pareja Del Año
# 1                                        Fiel
# 2                          Flamenco y Bachata
# 3                                          AM
# 4                                     Búmeran
# ..                                        ...
# 96   Jerusalema (feat. Nomcebo Zikode) [Edit]
# 97                                    Poblado
# 98                                  Sonqueson
# 99                                Inside News
# 100
#
#                                         artist
# 0               Myke Towers,   Sebastián Yatra
# 1        Jhay Cortez,  Los Legendarios,  Wisin
# 2                           Daviles de Novelda
# 3                   Flow La Movie,  Nio García
# 4                                       Beluga
# ..                                         ...
# 96                                   Master KG
# 97   Totoy El Frio,  Natan & Shander,  Crissin
# 98                                 La Pegatina
# 99                 Warner/Chappell Productions
# 100       Los Legendarios, Wisin & Jhay Cortez
#
# [101 rows x 2 columns]

# %%
topspain = topspain.drop(labels=100, axis=0)

# %% [markdown]
# Top from UK

# %%
url2 = "https://www.top-charts.com/songs/all-genres/united-kingdom/total/2021-W18"

# %%
response = requests.get(url2)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, minimal-ui, initial-scale=1, maximum-scale=5" name="viewport"/>
#   <meta content="Chart of the Top 100  songs in United Kingdom. The most listened songs around the world." name="description"/>
#   <meta content="https://www.top-charts.com/songs/all-genres/united-kingdom/total/2021-W18" property="al:web:url"/>
#   <meta content="United Kingdom Top 100  Songs" property="og:title"/>
#   <meta content="https://www.top-charts.com/songs/all-genres/united-kingdom/total/2021-W18" property="og:url"/>
#   <meta content="Chart of the Top 100  songs in United Kingdom. The most listened songs around the world." property="og:description"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="United Kingdom Top 100  Songs" name="twitter:title"/>
#   <meta content="https://www.top-charts.com/songs/all-genres/united-kingdom/total/2021-W18" name="twitter:url"/>
#   <meta content="Chart of the Top 100  songs in United Kingdom. The most listened songs around the world." name="twitter:description"/>
#   <meta content="" name="theme-color"/>
#   <link href="https://www.top-charts.com/songs/all-genres/united-kingdom/total/2021-W18" rel="canonical"/>
#   <title>
#    United Kingdom Top 100 Songs Chart | Top Charts
#   </title>
#   <link href="https://cdn.top-charts.com/static/images/fav.png" rel="shortcut icon" type="image/png"/>
#   <link href="https://www.google-analytics.com/" rel="preconnect"/>
#   <link href="https://cdn.top-charts.com/" rel="preconnect"/>
#   <link href="//www.googletagservices.com" rel="dns-prefetch"/>
#   <link href="https://www.google.com" rel="dns-prefetch"/>
#   <link href="http://www.google.com" rel="dns-prefetch"/>
#   <link href="https://tpc.googlesyndication.com" rel="dns-prefetch"/>
#   <link href="https://fonts.googleapis.com" rel="dns-prefetch"/>
#   <link href="https://fonts.gstatic.com" rel="dns-prefetch"/>
#   <link href="https://ajax.googleapis.com" rel="dns-prefetch"/>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-41201130-43">
#   </script>
#   <script>
#    window.dataLayer=window.dataLayer||[];function gtag(){dataLayer.push(arguments);}
# gtag('js',new Date());gtag('config','UA-41201130-43');;
#   </script>
#   <link href="https://cdn.top-charts.com/static/css/main.min.css?9d2b8f9e" rel="stylesheet"/>
#   <link href="https://cdn.top-charts.com/static/css/navbar.min.css?10b69daf" rel="stylesheet"/>
#   <style>
#    @media (max-width: 992px) { .li:not(.show) { display: none; } .navbar-collapse { flex-basis: 0; width: fit-content; flex-grow: 0; } .navbar-brand { margin-right: 0; } .hide-992 { display: none !important; } .margin-hamb { margin-right: 8px; } } @media (max-width: 1200px) { .border-col-search { border-color: transparent !important; } } @media (min-width: 992px) { .show-992 { display: flex; } .flex-grow-992 { flex-grow: 1; } } .search-grad, .search-grad:before { background: linear-gradient(237.66deg, #813D3D 0%, #FF8D8D 100%); -webkit-background-clip: text; -webkit-text-fill-color: transparent; display: initial; /* reset Font Awesome's display:inline-block */ } /* background: linear-gradient(487.66deg, #f9f4f4, #fdd7d7 100%); */ .top-charts-header-font { width: 74px; color: #707d8a !important; font-size: 15px; font-weight: bold; line-height: 18px; } .image-on-bar { height: 53px; width: 52px; border-radius: 6px; background: linear-gradient(313.06deg, rgba(172, 38, 38, 0.5) 0%, rgba(255, 255, 255, 0) 37.87%, rgba(255, 255, 255, 0.25) 71.36%, rgba(255, 255, 255, 0.5) 100%); } .rank-position-icon { width: 19px; height: 19px; } @media (min-width: 576px) { .image-on-bar { height: 72px; width: 71px; } .rank-position-icon { height: 26px; width: auto; } } @media (min-width: 1200px) { .image-on-bar { height: 79px; width: 78px; } .rank-position-icon { height: 30px; width: auto; } } .song-card { border-radius: 5px; background-color: #FFFFFF; box-shadow: 0 1px 0 0 rgba(0, 0, 0, 0.09); } body { background-color: #F9F9F9; } .marg-alb-card { padding-top: 5px; padding-bottom: 5px; } .song-text { color: #6C6C6C; /*#383d41e3;*/ font-family: Roboto; font-size: 13px; font-weight: bold; line-height: 15px; margin-bottom: 2%; } @media (min-width: 576px) { .song-text { margin-bottom: 1%; font-size: 17px; line-height: 20px; } } @media (min-width: 992px) { .song-text { margin-bottom: 1%; font-size: 20px; line-height: 24px; } } @media (min-width: 1200px) { .song-text { font-size: 23px; font-weight: bold; line-height: 27px; } } .artist-text { color: #434343b5; font-family: Roboto; font-size: 12px; line-height: 14px; } @media (min-width: 576px) { .artist-text { font-size: 16px; line-height: 19px; } } @media (min-width: 576px) { .artist-text { font-size: 18px; line-height: 21px; } } @media (min-width: 1200px) { .artist-text { font-size: 20px; line-height: 24px; } } @media (max-width: 380px) { .no-wrap { flex-wrap: nowrap; } } .cont-song-margin { margin-left: 10px; margin-right: 10px; } @media (min-width: 576px) { .cont-song-margin { margin-left: 15px; margin-right: 15px; } } .songs-margin { margin-bottom: 5px; } .top-chart-title-style { background-color: white; box-shadow: 0 1px 0 0 rgba(0, 0, 0, .09); } @media (min-width: 576px) { .top-chart-title-style { margin-left: 15px; margin-right: 15px; border-radius: 5px; background-color: white; box-shadow: 0 1px 0 0 rgba(0, 0, 0, .09); } } .song-size { min-height: 60px; } @media (min-width: 576px) { .song-size { min-height: 80px; } } .container-img-text { position: relative; text-align: center; color: white; } /* Bottom left text */ .bottom-left { position: absolute; bottom: 8px; left: 16px; } /* Top left text */ .top-left { position: absolute; top: 8px; left: 16px; } /* Top right text */ .top-right { position: absolute; top: 8px; right: 16px; } /* Bottom right text */ .bottom-right { position: absolute; bottom: 8px; right: 16px; } /* Centered text */ .centered { position: absolute; top: 50%; left: 50%; transform: translate(-50%, -50%); } .play-icon-size { font-size: 30px; } @media (min-width: 1200px) { .play-icon-size { font-size: 45px; } } .icon-size-label { font-size: 35px; } .top-chart-title-text { background: -webkit-linear-gradient(130deg, rgba(178, 70, 70, 1) 0%, rgba(252, 114, 114, 0.72) 100%); -webkit-background-clip: text; -webkit-text-fill-color: transparent; font-family: Roboto; font-size: 15px; font-weight: 900; line-height: 18px; text-shadow: 1px 2px rgba(0, 0, 0, 0.1); } @media (min-width: 576px)  ...
#   </style>
#   <link href="https://fonts.googleapis.com/css?family=Lobster|Righteous|Roboto:400,700,900&amp;display=swap" rel="stylesheet"/>
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/5.11.2/css/all.css" rel="stylesheet"/>
#   <script src="https://code.jquery.com/jquery-3.4.1.slim.min.js">
#   </script>
#   <script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.7/umd/popper.min.js">
#   </script>
#   <script defer="" src="https://cdn.top-charts.com/static/js/packed.min.js?c0a8852b" type="text/javascript">
#   </script>
#   <meta content="{198664883831591}" property="fb:app_id"/>
#   <link href="https://www.top-charts.com/songs/all-genres/united-kingdom/total/2021-W18" hreflang="en" rel="alternate"/>
#   <link href="https://www.top-charts.com/pt/musicas/generos-musicais/reino-unido/total/2021-W18" hreflang="pt" rel="alternate"/>
#   <link href="https://www.top-charts.com/es/canciones/generos-musicales/reino-unido/total/2021-W18" hreflang="es" rel="alternate"/>
#   <link href="https://www.top-charts.com/songs/all-genres/united-kingdom/total/2021-W18" hreflang="x-default" rel="alternate"/>
#   <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <script>
#    window.googletag = window.googletag || {cmd: []};
#         googletag.cmd.push(function () {
#             var stickyMapping = googletag.sizeMapping().addSize([1200, 300], [[300, 600], [160, 600]]).// Desktop
#                 addSize([0, 0], []).build();
#
#             var MappingDesktopUnderMusic = googletag.sizeMapping().addSize([728, 45], [728, 90]).// Desktop
#                 addSize([0, 0], []).build();
#
#             var MappingDesktopUpPlatform = googletag.sizeMapping().addSize([1200, 100], [[336, 280], [300, 250]]).// Desktop
#                 addSize([0, 0], []).build();
#
#
#             // This mapping will only display ads when user is on mobile or tablet sized viewport
#             var MappingMobileHeader = googletag.sizeMapping().addSize([768, 90], []).addSize([320, 50], [320, 100]).// Tablet // Desktop
#                 addSize([0, 0], []).build();
#
#             var MappingMobileUnderMusic = googletag.sizeMapping().addSize([728, 90], []).// Desktop
#                 addSize([300, 125], [300, 250]).// Tablet
#                 addSize([0, 0], []).build();
#             if (window.innerWidth < 728) {
#                 googletag.defineSlot('/62660943/topcharts_mobile_homepage/topcharts_mobile_topsongs', [[320, 50], [320, 100]], 'div-gpt-ad-header').defineSizeMapping(MappingMobileHeader).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_mobile_homepage/topcharts_mobile_topsongs', [[300, 250]], 'div-gpt-ad-under-music-mob19').defineSizeMapping(MappingMobileUnderMusic).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_mobile_homepage/topcharts_mobile_topsongs', [[300, 250]], 'div-gpt-ad-under-music-mob39').defineSizeMapping(MappingMobileUnderMusic).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_mobile_homepage/topcharts_mobile_topsongs', [[300, 250]], 'div-gpt-ad-under-music-mob59').defineSizeMapping(MappingMobileUnderMusic).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_mobile_homepage/topcharts_mobile_topsongs', [[300, 250]], 'div-gpt-ad-under-music-mob79').defineSizeMapping(MappingMobileUnderMusic).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_mobile_homepage/topcharts_mobile_topsongs', [[300, 250]], 'div-gpt-ad-under-music-mob99').defineSizeMapping(MappingMobileUnderMusic).addService(googletag.pubads());
#             }
#             else {
#                 googletag.defineSlot('/62660943/topcharts_desktop_homepage/topcharts_desktop_stickyads', [[300, 600], [160, 600]], 'div-gpt-ad-sticky-ad').defineSizeMapping(stickyMapping).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_desktop_homepage/topcharts_desktop_topsongs', [[336, 280], [300, 250]], 'div-gpt-ad-up-platform').defineSizeMapping(MappingDesktopUpPlatform).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_desktop_homepage/topcharts_desktop_topsongs', [[728, 90]], 'div-gpt-ad-under-music-desk19').defineSizeMapping(MappingDesktopUnderMusic).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_desktop_homepage/topcharts_desktop_topsongs', [[728, 90]], 'div-gpt-ad-under-music-desk39').defineSizeMapping(MappingDesktopUnderMusic).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_desktop_homepage/topcharts_desktop_topsongs', [[728, 90]], 'div-gpt-ad-under-music-desk59').defineSizeMapping(MappingDesktopUnderMusic).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_desktop_homepage/topcharts_desktop_topsongs', [[728, 90]], 'div-gpt-ad-under-music-desk79').defineSizeMapping(MappingDesktopUnderMusic).addService(googletag.pubads());
#                 googletag.defineSlot('/62660943/topcharts_desktop_homepage/topcharts_desktop_topsongs', [[728, 90]], 'div-gpt-ad-under-music-desk99').defineSizeMapping(MappingDesktopUnderMusic).addService(googletag.pubads());
#             }
#             googletag.pubads().enableSingleRequest();
#             googletag.pubads().collapseEmptyDivs();
#             googletag.enableServices();
#         });
#   </script>
#  </head>
#  <body>
#   <div id="fb-root">
#   </div>
#   <script async="" crossorigin="anonymous" defer="" src="https://connect.facebook.net/pt_PT/sdk.js#xfbml=1&amp;version=v5.0">
#   </script>
#   <link href="https://cdn.top-charts.com/static/css/top_songs.min.css?dae43232" rel="stylesheet" type="text/css"/>
#   <link href="https://cdn.top-charts.com/static/css/datetimepicker.min.css?74c5af5c" rel="stylesheet" type="text/css"/>
#   <header id="header" style="background-color: white">
#    <div class="container p-0 container-max-width">
#     <div class="container-fluid container-header-size">
#      <nav class="navbar navbar-expand-lg navbar-light navbar-details p-0 pt-lg-4" style="background-color: white">
#       <div class="row w-100 m-0 justify-content-between">
#        <div class="col-6 col-sm-5 col-lg-1">
#         <a class="navbar-brand pb-0" href="/">
#          <img alt="Top Charts" src="https://cdn.top-charts.com/static/images/logo_topcharts.svg" style="height: 33px"/>
#         </a>
#        </div>
#        <div class="col-6 col-sm-7 col-lg-6 col-xl-11 d-flex pr-0 flex-row-reverse flex-xl-row align-items-center align-items-xl-end justify-content-lg-around">
#         <div class="col-6 col-lg-7 adjust-max-width p-0 ml-sm-3">
#          <button aria-controls="navbarTogglerDemo02" aria-expanded="false" aria-label="Toggle navigation" class="border-col-search pl-0 no-outline hide-at-1200" data-target="#modalNavigation" data-toggle="modal" style="background-color: transparent;z-index: 2" type="button">
#           <i class="fas fa-align-justify search-grad">
#           </i>
#          </button>
#          <div class="show-at-1200 collapse navbar-collapse flex-lg-grow-0" id="navbarTogglerDemo02">
#           <ul class="navbar-nav mr-auto mt-2 mt-lg-0 flex-grow-1 justify-content-around align-items-center">
#            <li class="nav-item mx-1" id="/songs">
#             <a class="nav-link header header-titles-text" href="/songs">
#              Top Songs
#              <span class="sr-only">
#               (current)
#              </span>
#             </a>
#            </li>
#            <li class="nav-item mx-1">
#             <a class="nav-link header-titles-text" href="/albums">
#              Top Albums
#             </a>
#            </li>
#            <li class="nav-item mx-1">
#             <a class="nav-link header-titles-text" href="/artists">
#              Artists
#             </a>
#            </li>
#            <li class="nav-item mx-1" id="/genres">
#             <a class="nav-link header-titles-text" href="/genres">
#              Genres
#             </a>
#            </li>
#            <li id="platform_dropdown">
#             <div class="dropdown header-titles-text">
#              <a class="dropdown-toggle header-titles-text" data-toggle="dropdown" role="button" type="button">
#               Platforms
#              </a>
#              <ul class="dropdown-menu dropdown-text" id="dropdownPlatforms">
#               <li class="dropdown-submenu hover-effect">
#                <a class="test" href="#" tabindex="-1">
#                 Apple Music
#                 <i class="fas fa-caret-right ml-1">
#                 </i>
#                </a>
#                <ul class="dropdown-menu dropdown-text">
#                 <li>
#                  <a href="/albums/all-genres/worldwide/apple-music" tabindex="-1">
#                   Albums
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/songs/all-genres/worldwide/apple-music" tabindex="-1">
#                   Songs
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li class="dropdown-submenu hover-effect">
#                <a class="test" href="#" tabindex="-1">
#                 iTunes
#                 <i class="fas fa-caret-right ml-1">
#                 </i>
#                </a>
#                <ul class="dropdown-menu dropdown-text">
#                 <li>
#                  <a href="/albums/all-genres/worldwide/itunes" tabindex="-1">
#                   Albums
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/songs/all-genres/worldwide/itunes" tabindex="-1">
#                   Songs
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li class="hover-effect">
#                <a href="/songs/all-genres/worldwide/radio" tabindex="-1">
#                 Radio Stations
#                </a>
#               </li>
#               <li class="hover-effect">
#                <a href="/songs/all-genres/worldwide/spotify" tabindex="-1">
#                 Spotify
#                </a>
#               </li>
#               <li class="dropdown-submenu hover-effect">
#                <a class="test" href="#" tabindex="-1">
#                 Top Charts
#                 <i class="fas fa-caret-right ml-1">
#                 </i>
#                </a>
#                <ul class="dropdown-menu dropdown-text">
#                 <li>
#                  <a href="/albums/all-genres/worldwide/total" tabindex="-1">
#                   Albums
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/songs/all-genres/worldwide/total" tabindex="-1">
#                   Songs
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li class="hover-effect">
#                <a href="/songs/all-genres/worldwide/youtube" tabindex="-1">
#                 Youtube
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#            <li class="nav-item mx-1" id="/map">
#             <a class="nav-link header-titles-text" href="/map">
#              Map
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="col-6 col-lg-4 p-0 d-flex flex-grow-1 fit-content-till-576">
#          <form action="/search" class="li form-inline search-icon my-lg-0 show w-100 show-at-576" method="get">
#           <div class="row m-0 header-search-border w-100">
#            <div class="input-group col-sm-12 pr-0 p-lg-0 mr-3">
#             <input class="form-control py-2 border-0 show-at-576 header-search-input" id="search-input" name="q" placeholder="Artist - Song - Album" type="text" value=""/>
#             <span class="input-group-append">
#              <button class="btn border-0" type="submit">
#               <i class="fa fa-search fa search-grad">
#               </i>
#              </button>
#             </span>
#            </div>
#           </div>
#          </form>
#          <form action="/search" class="li form-inline search-icon my-lg-0 show w-100 hide-at-576" method="get">
#           <div class="row header-search-border w-100">
#            <div class="input-group col-sm-12 pr-0 p-lg-0 mr-3">
#             <input class="form-control py-2 border-0 show-at-576 header-search-input" id="search-input" name="q" placeholder="Artist - Song - Album" type="text" value=""/>
#             <span class="input-group-append">
#              <button class="btn border-0" id="search" type="button">
#               <i class="fa fa-search fa search-grad">
#               </i>
#              </button>
#             </span>
#            </div>
#           </div>
#          </form>
#         </div>
#         <div class="col-lg-1 max-width-fit">
#          <div class="row m-0 align-items-baseline show-at-1200 generic-language">
#           <div class="col-4 max-width-fit px-1">
#            <div class="dropdown">
#             <button aria-expanded="false" aria-haspopup="true" class="btn btn-secondary dropdown-toggle generic-language-button pl-0" data-toggle="dropdown" id="dropdownMenuButton" type="button">
#              EN
#             </button>
#             <div aria-labelledby="dropdownMenuButton" class="dropdown-menu generic-language-dropdown">
#              <a class="dropdown-item color-grey" href="/pt/musicas/generos-musicais/reino-unido/total/2021-W18">
#               PT
#              </a>
#              <a class="dropdown-item color-grey" href="/es/canciones/generos-musicales/reino-unido/total/2021-W18">
#               ES
#              </a>
#              <a class="dropdown-item color-grey" href="/songs/all-genres/united-kingdom/total/2021-W18">
#               EN
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </nav>
#     </div>
#     <div aria-hidden="true" aria-labelledby="exampleModalLabel" class="modal fade" id="modalNavigation" role="dialog" tabindex="-1">
#      <div class="modal-dialog h-100 w-100 m-0" role="document">
#       <div class="modal-content w-100 h-100" style="background: linear-gradient(164.7deg, rgb(0, 0, 0) 0%, rgb(39, 9, 6) 100%);">
#        <div class="modal-header align-items-center">
#         <img alt="Top Charts" class="img-fluid" src="https://cdn.top-charts.com/static/images/logo_topcharts_modal.svg"/>
#         <button aria-label="Close" class="close" data-dismiss="modal" style="opacity: 1;" type="button">
#          <i class="far fa-times-circle" style="color: white; text-shadow: 0 0">
#          </i>
#         </button>
#        </div>
#        <div class="modal-body modal-list-hover p-0">
#         <nav class="list-group">
#          <div class="hamburger-links hamburger-text-style align-items-center px-3" onclick="showDropdown('dropdown1');addRemoveCaret('modal-option-1')" style="height: 48px">
#           <a class="list-group-item p-0" href="/songs">
#            Top Songs
#           </a>
#           <button aria-expanded="false" aria-haspopup="true" class="btn pr-1" style="color: white" type="button">
#            <i class="fas fa-caret-down" id="modal-option-1">
#            </i>
#           </button>
#          </div>
#          <div class="list-group" id="dropdown1" style="display: none;background: linear-gradient(133.29deg,
#                             rgba(252,114,114,0.72) 0%, #B24646 100%);">
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/songs/all-genres/united-kingdom/apple-music">
#             Apple Music Songs
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#           <div class="dropdown-divider modal-dropdown-margin">
#           </div>
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/songs/all-genres/united-kingdom/itunes">
#             iTunes Songs
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#           <div class="dropdown-divider modal-dropdown-margin">
#           </div>
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/songs/all-genres/united-kingdom/radio">
#             Radio songs
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#           <div class="dropdown-divider modal-dropdown-margin">
#           </div>
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/songs/all-genres/united-kingdom/spotify">
#             Spotify songs
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#           <div class="dropdown-divider modal-dropdown-margin">
#           </div>
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/songs/all-genres/united-kingdom/youtube">
#             Youtube
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#           <div class="dropdown-divider modal-dropdown-margin">
#           </div>
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/songs/all-genres/united-kingdom/total">
#             Total
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#          </div>
#          <div class="row m-0 hamburger-text-style modal-items-rows">
#           <a class="list-group-item modal-items" href="/genres">
#            Genres
#            <i aria-hidden="true" class="fas fa-caret-right" id="modal-option-4">
#            </i>
#           </a>
#          </div>
#          <div class="hamburger-links hamburger-text-style align-items-center px-3" onclick="showDropdown('dropdown2');addRemoveCaret('modal-option-2')" style="height: 48px">
#           <a class="list-group-item p-0">
#            Languages
#           </a>
#           <button aria-expanded="false" aria-haspopup="true" class="btn pr-1" style="color: white" type="button">
#            <i class="fas fa-caret-down" id="modal-option-2">
#            </i>
#           </button>
#          </div>
#          <div class="list-group" id="dropdown2" style="display: none;background: linear-gradient(133.29deg,
#                             rgba(252,114,114,0.72) 0%, #B24646 100%);">
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/pt/musicas/generos-musicais/reino-unido/total/2021-W18">
#             Portuguese
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#           <div class="dropdown-divider modal-dropdown-margin">
#           </div>
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/es/canciones/generos-musicales/reino-unido/total/2021-W18">
#             Spanish
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#           <div class="dropdown-divider modal-dropdown-margin">
#           </div>
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/songs/all-genres/united-kingdom/total/2021-W18">
#             English
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#          </div>
#          <div class="hamburger-links hamburger-text-style align-items-center px-3" onclick="showDropdown('dropdown3');addRemoveCaret('modal-option-3')" style=" height: 48px">
#           <a class="list-group-item p-0" href="/albums">
#            Top Albums
#           </a>
#           <button aria-expanded="false" aria-haspopup="true" class="btn pr-1" style="color: white" type="button">
#            <i class="fas fa-caret-down" id="modal-option-3">
#            </i>
#           </button>
#          </div>
#          <div class="list-group" id="dropdown3" style="display: none;background: linear-gradient(133.29deg,
#                             rgba(252,114,114,0.72) 0%, #B24646 100%);">
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/albums/all-genres/united-kingdom/apple-music">
#             Apple Music Albums
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#           <div class="dropdown-divider modal-dropdown-margin">
#           </div>
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/albums/all-genres/united-kingdom/itunes">
#             iTunes Albums
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#           <div class="dropdown-divider modal-dropdown-margin">
#           </div>
#           <div class="row m-0 hamburger-text-style">
#            <a class="list-group-item adjust-center px-5 modal-items-href" href="/albums/all-genres/united-kingdom/total">
#             Top Albums
#             <i aria-hidden="true" class="fas fa-caret-right">
#             </i>
#            </a>
#           </div>
#          </div>
#          <div class="row m-0 hamburger-text-style modal-items-rows" disabled="">
#           <a class="list-group-item modal-items" href="/artists">
#            Artists
#            <i aria-hidden="true" class="fas fa-caret-right" id="modal-option-3">
#            </i>
#           </a>
#          </div>
#          <div class="row m-0 hamburger-text-style modal-items-rows">
#           <a class="list-group-item modal-items" href="/map">
#            Map
#            <i aria-hidden="true" class="fas fa-caret-right" id="modal-option-4">
#            </i>
#           </a>
#          </div>
#         </nav>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="container mt-2 mb-2 hide-small-input" id="search-box">
#      <div class="row">
#       <div class="col-12">
#        <form action="/search" method="get">
#         <div class="input-group col-12 p-0">
#          <input class="form-control py-2 border-right-0 search-sug-placeholder" id="example-search-input" name="q" placeholder="Artist - Song - Album" style="box-shadow: inset 0 2px 1px 0 rgba(0,0,0,0.19);border-radius: 12px 0 0 12px;border: 0 !important;" type="search" value=""/>
#          <span class="input-group-append">
#           <button class="btn btn-outline-secondary border-left-0 border" style="border-radius: 0px 12px 12px 0px;
#                         box-shadow: inset -1px 2px 1px 0 rgba(0,0,0,0.19);
#                         background-color: white;
#                         border: 0 !important;" type="submit">
#            <i aria-hidden="true" class="fa fa-search fa search-grad" style="opacity: 0.50;">
#            </i>
#           </button>
#          </span>
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#   </header>
#   <div class="row m-0 container-border-genre">
#   </div>
#   <div class="row mx-0 justify-content-center hide-at-768 mb-1">
#    <div class="lawmaker-320-100" id="law-maker-2">
#     <div id="div-gpt-ad-header">
#      <script>
#       googletag.cmd.push(function () {
#                             googletag.display('div-gpt-ad-header');
#                         });
#      </script>
#     </div>
#    </div>
#   </div>
#   <div class="container-fluid hide-at-1200" style="background-color: white">
#    <div class="row align-items-center justify-content-between just row-title" style="box-shadow: 0 1px 0 0 rgba(0,0,0,.09);">
#     <div class="col-10 col-sm-10 top-chart-title-text">
#      <div class="row justify-content-cente align-items-center">
#       <div class="col-2 max-width-fit p-0 ml-3 mr-1 d-flex flex-row top-char-country-flag-expand">
#        <img alt="United Kingdom" class="img-fluid top-country-flag-size" src="https://cdn.top-charts.com/static/countries/gb.png"/>
#        <div class="overlay-grad-flag">
#        </div>
#       </div>
#       <div class="col-9 col-sm-10">
#        <div class="row">
#         <span class="top-chart-country-text">
#          United Kingdom
#         </span>
#        </div>
#        <div class="row">
#         <span class="top-chart-title-text">
#          Top 100 Songs
#         </span>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="col-2 pl-0 max-width-fit text-right">
#      <img alt="android_ios" class="android-share share-button-img" data-target="#modalShare" data-toggle="modal" id="android" src="https://cdn.top-charts.com/static/images/Share_Android.svg"/>
#      <img alt="android_ios" class="ios-share share-button-img" data-target="#modalShare" data-toggle="modal" id="ios" src="https://cdn.top-charts.com/static/images/Share_IOS.svg"/>
#      <div aria-hidden="true" aria-labelledby="exampleModalLabel" class="modal fade" id="modalShare" role="dialog" tabindex="-1">
#       <div class="modal-dialog modal-share fixed-bottom w-100 m-0" role="document">
#        <div class="modal-content">
#         <div class="modal-header">
#          <div class="row align-items-center justify-content-sm-between just row-title w-100">
#           <div class="col-12 col-sm-12 top-chart-title-text">
#            <div class="row justify-content-cente align-items-center">
#             <div class="col-4 max-width-fit p-0 ml-3 mr-1 d-flex flex-row top-char-country-flag-expand">
#              <img alt="United Kingdom" class="img-fluid top-country-flag-size" src="https://cdn.top-charts.com/static/countries/gb.png"/>
#              <div class="overlay-grad-flag">
#              </div>
#             </div>
#             <div class="col-8">
#              <div class="row top-chart-country-text">
#               United Kingdom
#              </div>
#              <div class="row top-chart-title-text">
#               Top 100 Songs
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#           <span aria-hidden="true">
#            ×
#           </span>
#          </button>
#         </div>
#         <div class="modal-body">
#          <div class="row flex-column flex-sm-row align-items-center">
#           <div class="col-4 text-center my-1 p-0">
#            <a aria-pressed="true" class="btn btn-primary share-buttons text-nowrap" href="http://www.facebook.com/sharer.php?u=https://www.top-charts.com/songs/all-genres/united-kingdom/total/2021-W18" role="button">
#             <i aria-hidden="true" class="fab fa-facebook-f song-dropdown-social-icons mr-1">
#             </i>
#             Facebook
#            </a>
#           </div>
#           <div class="col-4 text-center my-1 p-0">
#            <a aria-pressed="true" class="btn btn-primary share-buttons text-nowrap" href="http://twitter.com/share?text=https://www.top-charts.com/songs/all-genres/united-kingdom/total/2021-W18" role="button" style="min-width: 80px">
#             <i aria-hidden="true" class="fab fa-twitter song-dropdown-social-icons mr-1">
#             </i>
#             Twitter
#            </a>
#           </div>
#           <div class="col-4 text-center my-1 p-0">
#            <a aria-pressed="true" class="btn btn-primary share-buttons text-nowrap" href="https://api.whatsapp.com/send?text=https://www.top-charts.com/songs/all-genres/united-kingdom/total/2021-W18" role="button">
#             <i aria-hidden="true" class="fab fa-whatsapp song-dropdown-social-icons mr-1">
#             </i>
#             Whatsapp
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="container-fluid d-flex flex-column justify-content-center top-songs-grad-box justify-content-xl-center">
#    <div class="row justify-content-xl-center align-items-xl-center show-at-1200">
#     <div class="col-xl-2 max-width-fit p-0 ml-3 mr-1 mb-1 d-flex flex-row top-char-country-flag-expand align-self-end">
#      <img alt="country" class="img-fluid top-country-flag-size-with-border" src="https://cdn.top-charts.com/static/countries/gb.png"/>
#      <div class="overlay-grad-flag">
#      </div>
#     </div>
#     <div class="col-xl-10 max-width-fit">
#      <h1 style="font-size: 0">
#       <span class="grad-logos-text-small">
#        United Kingdom
#       </span>
#       <br/>
#       <span class="top-search-title-style top-search-line">
#        Top 100 Songs
#       </span>
#      </h1>
#     </div>
#    </div>
#    <div class="row m-0 mb-2 justify-content-center">
#     <div class="container-max-width-1200 w-100">
#      <div class="col-12 p-0">
#       <form>
#        <div class="form-group row mx-sm-0 align-items-center justify-content-md-center mb-2 mb-xl-3">
#         <label class="px-1 col-3 col-md-2 col-xl-3 text-truncate col-form-label text-center text-xl-right pr-xl-60 top-search-form-labels" for="week">
#          The Week of
#         </label>
#         <div class="mr-3 form-cols" id="week_of">
#          <div class="input-group form-control top-search-form-placeholders form-border-radius" id="DateDemo">
#           <input class="top-search-form-placeholders w-100 text-truncate" id="weeklyDatePicker" onclick="addColorToSelectedWeek()" placeholder="Select Week" type="text"/>
#          </div>
#         </div>
#        </div>
#        <div class="form-group row mx-sm-0 align-items-center justify-content-md-center mb-2 mb-xl-3 flex-nowrap">
#         <label class="pr-1 col-3 col-md-2 col-xl-3 text-truncate text-center text-xl-right pr-xl-60 col-form-label top-search-form-labels" for="genre">
#          Genre
#         </label>
#         <div class="mr-3 form-cols" id="genre_col">
#          <select class="form-control pr-45 round top-search-form-placeholders form-border-radius text-truncate" id="genre" name="genre">
#           <option value="all-genres">
#            All Genres
#           </option>
#           <option value="alternative">
#            Alternative
#           </option>
#           <option value="blues">
#            Blues
#           </option>
#           <option value="christian-gospel">
#            Christian &amp; Gospel
#           </option>
#           <option value="classical">
#            Classical
#           </option>
#           <option value="country">
#            Country
#           </option>
#           <option value="dance">
#            Dance
#           </option>
#           <option value="electronic">
#            Electronic
#           </option>
#           <option value="hip-hop-rap">
#            Hip-Hop/Rap
#           </option>
#           <option value="jazz">
#            Jazz
#           </option>
#           <option value="latin">
#            Latin
#           </option>
#           <option value="pop">
#            Pop
#           </option>
#           <option value="rb-soul">
#            R&amp;B/Soul
#           </option>
#           <option value="reggae">
#            Reggae
#           </option>
#           <option value="rock">
#            Rock
#           </option>
#           <option value="world">
#            World
#           </option>
#          </select>
#         </div>
#        </div>
#        <div class="form-group row mx-sm-0 align-items-center justify-content-md-center mb-2 mb-xl-3">
#         <label class="col-3 col-md-2 col-xl-3 text-truncate pr-1 text-center text-xl-right pr-xl-60 col-form-label top-search-form-labels" for="country">
#          Country
#         </label>
#         <div class="mr-3 form-cols" id="country_col">
#          <select class="form-control round pr-45 top-search-form-placeholders form-border-radius" id="country" name="country">
#           <option value="united-kingdom">
#            United Kingdom
#           </option>
#           <option value="argentina">
#            Argentina
#           </option>
#           <option value="australia">
#            Australia
#           </option>
#           <option value="austria">
#            Austria
#           </option>
#           <option value="belgium">
#            Belgium
#           </option>
#           <option value="brazil">
#            Brazil
#           </option>
#           <option value="canada">
#            Canada
#           </option>
#           <option value="chile">
#            Chile
#           </option>
#           <option value="colombia">
#            Colombia
#           </option>
#           <option value="czech-republic">
#            Czech Republic
#           </option>
#           <option value="denmark">
#            Denmark
#           </option>
#           <option value="egypt">
#            Egypt
#           </option>
#           <option value="finland">
#            Finland
#           </option>
#           <option value="france">
#            France
#           </option>
#           <option value="germany">
#            Germany
#           </option>
#           <option value="greece">
#            Greece
#           </option>
#           <option value="hungary">
#            Hungary
#           </option>
#           <option value="india">
#            India
#           </option>
#           <option value="indonesia">
#            Indonesia
#           </option>
#           <option value="ireland">
#            Ireland
#           </option>
#           <option value="israel">
#            Israel
#           </option>
#           <option value="italy">
#            Italy
#           </option>
#           <option value="japan">
#            Japan
#           </option>
#           <option value="malaysia">
#            Malaysia
#           </option>
#           <option value="mexico">
#            Mexico
#           </option>
#           <option value="netherlands">
#            Netherlands
#           </option>
#           <option value="new-zealand">
#            New Zealand
#           </option>
#           <option value="nigeria">
#            Nigeria
#           </option>
#           <option value="norway">
#            Norway
#           </option>
#           <option value="peru">
#            Peru
#           </option>
#           <option value="philippines">
#            Philippines
#           </option>
#           <option value="poland">
#            Poland
#           </option>
#           <option value="portugal">
#            Portugal
#           </option>
#           <option value="singapore">
#            Singapore
#           </option>
#           <option value="south-africa">
#            South Africa
#           </option>
#           <option value="south-korea">
#            South Korea
#           </option>
#           <option value="spain">
#            Spain
#           </option>
#           <option value="sweden">
#            Sweden
#           </option>
#           <option value="switzerland">
#            Switzerland
#           </option>
#           <option value="taiwan">
#            Taiwan
#           </option>
#           <option value="thailand">
#            Thailand
#           </option>
#           <option value="turkey">
#            Turkey
#           </option>
#           <option value="ukraine">
#            Ukraine
#           </option>
#           <option value="united-arab-emirates">
#            United Arab Emirates
#           </option>
#           <option value="united-states">
#            United States
#           </option>
#           <option value="vietnam">
#            Vietnam
#           </option>
#           <option value="worldwide">
#            Worldwide
#           </option>
#          </select>
#         </div>
#        </div>
#       </form>
#      </div>
#      <div class="row mx-0 align-items-center justify-content-end justify-content-md-center mt-n1">
#       <div class="pr-sm-3 pr-md-2 pr-xl-4 mr-xl-2 col-md-8 p-0 methodology d-flex justify-content-end align-items-center">
#        <div class="mx-2">
#         <a href="/csv/all-genres/united-kingdom/total/2021-W18">
#          Download To CSV
#          <i class="ml-2 fas fa-download">
#          </i>
#          ,
#         </a>
#        </div>
#        <div class="d-flex flex-row justify-content-end">
#         <div class="row mr-1 max-width-fit m-0 align-items-center justify-content-end flex-nowrap" data-original-title="The Top 100 Songs chart ranks the most played songs of the week in 46 countries. The chart includes airplay from 15000 radio stations , iTunes downloads, Apple Music, Spotify and Youtube streams. The rank is updated weekly." data-placement="top" data-toggle="tooltip" title="">
#          <span class="mr-2">
#           Methodology
#          </span>
#          <img alt="methodology" class="methodology-icon" src="/static/images/methodology_icon.svg"/>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="container p-0 m-0 mt-n4 mx-sm-auto mx-xl-auto px-xl-0 container-max-width">
#    <div class="container-fluid mb-2 p-xl-0">
#     <div class="d-none">
#      <ul class="breadcrumb" itemscope="" itemtype="http://schema.org/BreadcrumbList">
#       <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#        <a href="/songs/all-genres/united-kingdom/total/2021-W18" itemprop="item">
#         <span itemprop="name">
#          Songs
#         </span>
#        </a>
#        <meta content="1" itemprop="position"/>
#       </li>
#       <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#        <a href="/songs/all-genres/united-kingdom/total/2021-W18" itemprop="item">
#         <span itemprop="name">
#          All Genres
#         </span>
#        </a>
#        <meta content="2" itemprop="position"/>
#       </li>
#       <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#        <a href="/songs/all-genres/united-kingdom/total/2021-W18" itemprop="item">
#         <span itemprop="name">
#          United Kingdom
#         </span>
#        </a>
#        <meta content="3" itemprop="position"/>
#       </li>
#      </ul>
#     </div>
#     <div class="row song-card songs-margin song-size align-items-center justify-content-between mx-n1 mx-sm-0" id="s1" itemscope="" itemtype="http://schema.org/MusicGroup">
#      <div class="col-10 d-flex align-items-center pl-0">
#       <div class="col-1 align-middle text-center info-detail-artist-numbers numbers-min-width max-width-fit p-0 ml-lg-2">
#        <span>
#         1
#        </span>
#       </div>
#       <div class="col-3 marg-alb-card mr-sm-1 img-size pl-0 pr-1 px-lg-2" onclick="playSelectedSong(0)">
#        <div class="container-img-text">
#         <img alt="Body artwork" class="image-on-bar" data-src="https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/62/31/73/62317311-25d1-1a01-20c5-33e4cdaf14b6/190296722134.jpg/60x60bb.jpeg" src="https://cdn.top-charts.com/static/images/loading.gif"/>
#         <img alt="play" class="centered song-card-play-button" id="1-img" src="https://cdn.top-charts.com/static/images/BT_Play.png"/>
#         <img alt="position-icon" class="top-left-corner rank-position-icon" src="https://cdn.top-charts.com/static/images/up_icon.svg"/>
#        </div>
#       </div>
#       <div class="col-8">
#        <div class="row song-text" id="title" style="">
#         <div class="col-12 p-0">
#          <span class="song-text" itemprop="track" itemscope="" itemtype="http://schema.org/MusicRecording">
#           <a href="/s/body-russ-millions-x-tion-wayne" itemprop="url">
#            <div class="text-truncate" itemprop="name">
#             Body
#            </div>
#           </a>
#          </span>
#         </div>
#        </div>
#        <div class="row artist-text text-color-sing" id="Artist">
#         <div class="col-12 p-0 text-truncate d-block">
#          <a href="/artist-detail/tion-wayne" itemprop="url">
#           <span itemprop="name">
#            Tion Wayne,
#           </span>
#          </a>
#          <a href="/artist-detail/russ-millions" itemprop="url">
#           <span itemprop="name">
#            Russ Millions
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="col-2 d-flex align-items-center justify-content-center">
#       <div class="btn-group dropdown">
#        <button aria-expanded="false" aria-haspopup="true" class="btn dropdown-toggle-split" onclick="showSongInfoDropDown(1);addRemoveCaret('caret1')" type="button">
#         <i class="fas fa-caret-up caret-active drop-colour drop-icon-size" id="caret1">
#         </i>
#        </button>
#       </div>
#      </div>
#      <div class="flex-column" id="1" style="width: 100%;">
#       <ul class="nav nav-tabs nav-fill" id="myTab" role="tablist">
#        <li class="nav-item">
#         <a aria-controls="home" aria-selected="true" class="nav-link active song-dropdown-options song-dropdown-options-active px-0" data-toggle="tab" href="#stats" id="stats-tab" onclick="showActiveTabs(this.id,'','')" role="tab">
#          STATS
#         </a>
#        </li>
#        <li class="nav-item">
#         <a aria-controls="profile" aria-selected="false" class="nav-link song-dropdown-options px-0" data-toggle="tab" href="#share" id="share-tab" onclick="showActiveTabs(this.id,'','')" role="tab">
#          SHARE
#         </a>
#        </li>
#        <li class="nav-item">
#         <a aria-controls="contact" aria-selected="false" class="nav-link song-dropdown-options px-0" data-toggle="tab" href="#go-to" id="go-to-tab" onclick="showActiveTabs(this.id,'','')" role="tab">
#          GO TO
#         </a>
#        </li>
#       </ul>
#       <div class="tab-content dropdown-info-size d-flex align-items-center" id="myTabContent">
#        <div aria-labelledby="stats-tab" class="tab-pane w-100 row m-0 fade show active" id="stats" role="tabpanel">
#         <div class="row m-0">
#          <div class="col-12 col-sm-8 col-xl-7 p-0 d-flex justify-content-around pt-2 d-flex flex-column">
#           <div class="row m-0">
#            <div class="col-4 p-0 width">
#             <div class="row m-0 info-card-song-stats mb-1 justify-content-center">
#              <span>
#               Last week
#              </span>
# ...
#   </script>
#   <script id="first_music" type="application/json">
#    {"position": 1, "song": {"song_id": 1559913126, "name": "Body", "artist_name": "Russ Millions x Tion Wayne", "present_in_top": true, "rating": "explicit", "artists_slugs": [{"artist_name": "Tion Wayne", "artist_slug": "tion-wayne"}, {"artist_name": "Russ Millions", "artist_slug": "russ-millions"}], "artwork_url_small": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/62/31/73/62317311-25d1-1a01-20c5-33e4cdaf14b6/190296722134.jpg/60x60bb.jpeg", "artwork_url_large": "https://is4-ssl.mzstatic.com/image/thumb/Music124/v4/62/31/73/62317311-25d1-1a01-20c5-33e4cdaf14b6/190296722134.jpg/170x170bb.jpeg", "release": "2021-03-25", "apple_music_view_url": "https://geo.music.apple.com/ie/album/body/1559913009?i=1559913126\u0026app=music\u0026mt=1\u0026at=11l64h\u0026ct=top-charts", "itunes_view_url": "https://geo.music.apple.com/ie/album/body/1559913009?i=1559913126\u0026app=itunes\u0026mt=1\u0026at=11l64h\u0026ct=top-charts", "preview_url": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview114/v4/e7/f5/5a/e7f55aba-ca0f-7ca9-68d0-2af45089912c/mzaf_803829139438219072.plus.aac.p.m4a", "slug": "body-russ-millions-x-tion-wayne"}, "peak_position": 1, "last_week": {"position": 2, "image": "up_icon.svg"}, "weeks_chart": 6}
#   </script>
#   <script defer="">
#    var first_music = ("first music", JSON.parse(document.getElementById('first_music').textContent));
#         var songs = JSON.parse(document.getElementById('songs').textContent);
#
#         songs.unshift(first_music);
#   </script>
#   <script defer="">
#    var audio;
#         var volume = 1;
#         var checker = 0;
#         var old_key = 0;
#         var song_array;
#         let current = 0;
#         var isAfter;
#
#
#         $('#audio-player').hide();
#         //Hide Pause
#         $('#pause').hide();
#
#         function initAudio() {
#
#
#             var song = song_array['preview_url'];
#             var title = song_array['name'];
#             var cover = song_array['artwork_url_large'];
#             var slug = song_array['slug'];
#             var artist = song_array['artist_name'];
#             var apple_music = song_array['apple_music_view_url'];
#             var itunes = song_array['itunes_view_url'];
#
#
#             //Create audio object
#             audio = new Audio(song);
#             audio.volume = volume;
#
#             audio.play().then(() => {
#                 $('#play').hide();
#                 $('#pause').show();
#                 showDuration();
#                 afterSongEnd();
#             }).catch(err => {
#                 if (isAfter) {
#                     return noPreviewUrl();
#                 }
#                 return noPreviewUrlBack(err);
#             });
#
#             //Insert audio info
#             $('.audio-song-artists').text(artist);
#             $('.audio-song-title').text(title);
#             $('#audio-itunes').attr('href', itunes);
#             $('#audio-song-href').attr('href', '/s/' + slug);
#             $('#audio-apple-music').attr('href', apple_music);
#             $('#audio-small-apple-music').attr('href', apple_music);
#             switchPlayImage();
#
#             //Insert song cover
#             $('img.audio-song-image').attr('src', cover);
#
#
#
#         }
#
#         function switchPlayImage() {
#             let value = current + 1;
#             if (checker === 0) {
#                 $("#" + value + "-img").attr('src', "https://cdn.top-charts.com/static/images/player_icons/audio_play.gif");
#                 checker++;
#                 old_key = current + 1
#             } else {
#
#                 $('#' + old_key + '-img').attr('src', "https://cdn.top-charts.com/static/images/BT_Play.png");
#                 old_key = value;
#                 $("#" + value + "-img").attr('src', "https://cdn.top-charts.com/static/images/player_icons/audio_play.gif");
#
#             }
#         }
#
#
#         //Play button
#         $('#play').click(function () {
#             audio.play();
#             $('#' + (current + 1) + '-img').attr('src', "https://cdn.top-charts.com/static/images/player_icons/audio_play.gif");
#             $('#play').hide();
#             $('#pause').show();
#             afterSongEnd();
#             showDuration();
#
#         });
#
#         //Pause button
#         $('#pause').click(function () {
#             audio.pause();
#             $('#' + (current + 1) + '-img').attr('src', "https://cdn.top-charts.com/static/images/BT_Play.png");
#             $('#play').show();
#             $('#pause').hide();
#         });
#
#         //Stop button
#         $('#stop').click(function () {
#             audio.pause();
#             audio.currentTime = 0;
#         });
#
#         //Next button
#         $('#next').click(function () {
#             isAfter = true;
#             audio.pause();
#             var next = current + 1;//position differs one pos more then normal array
#             //end of playlist
#             if (current === 99) {
#                 next = 0;
#             }
#             song_array = songs[next]['song'];
#             current = next;
#             initAudio();
#
#         });
#
#         //Prev button
#         $('#prev').click(function () {
#             isAfter = false;
#             audio.pause();
#             var previous = current - 1;//position differs two pos from array
#             //end of playlist
#             if (previous <= 0) {
#                 previous = 0;
#             }
#             song_array = songs[previous]['song'];
#             current = previous;
#             initAudio();
#         });
#
#         //Playlist song click
#         function playSelectedSong(id) {
#             marginFooterAudio();
#             $('#audio-player').show();
#             if (audio) {
#                 audio.pause();
#             }
#             current = id;
#             song_array = songs[id]['song'];
#             initAudio();
#
#         }
#
#
#         //Time/Duration
#         function showDuration() {
#             $(audio).bind('timeupdate', function () {
#                 //Get hours and minutes
#                 var s = parseInt(audio.currentTime % 60);
#                 var m = parseInt(audio.currentTime / 60) % 60;
#                 if (s < 10) {
#                     s = '0' + s;
#                 }
#                 $('#duration').html(m + ':' + s);
#                 var value = 0;
#                 if (audio.currentTime > 0) {
#                     value = Math.floor((100 / audio.duration) * audio.currentTime);
#                 }
#                 $('#ex1Slider .slider-selection ').css('width', value + '%');
#                 $('#ex1Slider .slider-handle').css('left', value + '%');
#             });
#         }
#
#         function afterSongEnd() {
#             $(audio).on('ended', function () {
#
#                 //Get hours and minutes
#
#                 if (audio.ended) {
#                     var next = current + 1;
#                     //end of playlist
#                     if (current === 98) {
#                         next = 0;
#                     }
#                     song_array = songs[next]['song'];
#                     current = next;
#                     initAudio();
#                 }
#             })
#         }
#
#
#         $(document).ready(function () {
#             $('#ex1').slider({
#                 formatter: function (value) {
#                 }
#             });
#         });
#
#
#
#
#          $('#ex1').on('slideStop', function (event) {
#             audio.currentTime = event.value;
#         });
#
#
#         $('#sound').on('click', function (event) {
#             if (audio.volume === 0) {
#                 audio.volume = volume;
#
#                 $('#ex2Slider .slider-selection ').css('width', audio.volume * 100 + '%');
#                 $('#ex2Slider .slider-handle').css('left', audio.volume * 100 + '%');
#                 return 0;
#             }
#             audio.volume = 0;
#             $('#ex2Slider .slider-selection ').css('width', 0 + '%');
#             $('#ex2Slider .slider-handle').css('left', 0 + '%');
#
#
#         });
#   </script>
#   <script>
#    function noPreviewUrl(err) {
#             var next = current + 1;
#             //end of playlist
#             if (current === 98) {
#                 next = 0;
#             }
#             song_array = songs[next]['song'];
#             current = next;
#             isAfter = true;
#             initAudio();
#         }
#
#         function noPreviewUrlBack(err) {
#             console.log(err);
#             var next = current - 1;
#             //end of playlist
#             if (current === 0) {
#                 next = 1;
#             }
#             song_array = songs[next]['song'];
#             current = next;
#             isAfter = false;
#             initAudio();
#
#         }
#   </script>
#   <script>
#    $(document).ready(function () {
#             $('.dropdown-submenu').hover(function (e) {
#                 console.log("elemento", $(this).children('ul'));
#                 $(this).children('ul').toggle();
#                 e.stopPropagation();
#                 e.preventDefault();
#             });
#         });
#   </script>
#   <script defer="">
#    function showActiveTabs(elementId, key, position) {
#             var style = "song-dropdown-options-active";
#             //Activate class on elementId and remove on others
#             $("#share-tab" + key + position).removeClass(style);
#             $("#stats-tab" + key + position).removeClass(style);
#             $("#go-to-tab" + key + position).removeClass(style);
#             $('#' + elementId).addClass(style);
#         }
#   </script>
#   <script defer="">
#    $(document).ready(function () {
#             $("img").unveil(200);
#         });
#   </script>
#   <script defer="">
#    $(document).ready(function () {
#             $('#ex2').slider({
#                 formatter: function (value) {
#
#                 }
#             });
#         });
#
#         $('#ex2').on('change', function (event) {
#             console.log('changed');
#             if (audio) {
#                 audio.volume = event.value.newValue/100;
#             }
#         });
#   </script>
#   <script defer="">
#    $(document).ready(function () {
#             $('[data-toggle="tooltip"]').tooltip();
#         });
#   </script>
#   <script defer="">
#    function addRemoveCaret(id) {
#
#             var element = document.getElementById(id);
#
#             if (element.classList.contains("fa-caret-down")) {
#                 element.classList.remove("fa-caret-down");
#                 element.classList.add("caret-active");
#                 element.classList.add("fa-caret-up");
#             } else {
#                 element.classList.remove("caret-active");
#                 element.classList.remove("fa-caret-up");
#                 element.classList.add("fa-caret-down");
#             }
#         }
#   </script>
#   <script>
#    function showDropdown(elementId) {
#             var x = document.getElementById(elementId);
#             if (x.style.display === "none") {
#                 x.style.display = "block";
#             } else {
#                 x.style.display = "none";
#             }
#         }
#   </script>
#   <script>
#    document.getElementById("search").addEventListener("click", redSearch, false);
#
#         function redSearch() {
#             var x = document.getElementById("search");
#             if (x.classList.contains('search-icon')) {
#                 x.classList.remove("search-icon");
#                 x.classList.add("box-shadow-0");
#             } else {
#                 x.classList.add("search-icon");
#             }
#         }
#   </script>
#   <script>
#    document.getElementById("search").addEventListener("click", showSearchContainer, false);
#
#         function showSearchContainer() {
#
#             var x = document.getElementById("search-box");
#
#             if (x.style.display === "none" || getComputedStyle(x, null).display === 'none') {
#                 x.style.display = "block";
#             } else {
#                 x.style.display = "none";
#             }
#         }
#   </script>
#   <script>
#    function marginFooterAudio() {
#             if (screen.width >= 576) {
#                 $("footer").css('margin-bottom', 68 + 'px');
#                 return 0;
#             }
#             $("footer").css('margin-bottom', 55 + 'px');
#
#         }
#   </script>
#  </body>
# </html>

# %%
soup.select("#title > div > span > a > div")
# Out:
# [<div class="text-truncate" itemprop="name">Body</div>,
#  <div class="text-truncate" itemprop="name">Peaches (feat. Daniel Caesar &amp; GIVĒON)</div>,
#  <div class="text-truncate" itemprop="name">Kiss Me More (feat. SZA)</div>,
#  <div class="text-truncate" itemprop="name">MONTERO (Call Me By Your Name)</div>,
#  <div class="text-truncate" itemprop="name">Confetti (feat. Saweetie)</div>,
#  <div class="text-truncate" itemprop="name">Something for the Pain (feat. Renee Six)</div>,
#  <div class="text-truncate" itemprop="name">Body (Remix) [feat. ArrDee, E1 (3x3), ZT (3x3), Bugzy Malone, Buni, Fivio Foreign &amp; Darkoo]</div>,
#  <div class="text-truncate" itemprop="name">Friday (feat. Mufasa &amp; Hypeman) [Dopamine Re-Edit]</div>,
#  <div class="text-truncate" itemprop="name">Levitating (feat. DaBaby)</div>,
#  <div class="text-truncate" itemprop="name">Your Power</div>,
#  <div class="text-truncate" itemprop="name">Let’s Go Home Together</div>,
#  <div class="text-truncate" itemprop="name">RAPSTAR</div>,
#  <div class="text-truncate" itemprop="name">The Business</div>,
#  <div class="text-truncate" itemprop="name">Little Bit of Love</div>,
#  <div class="text-truncate" itemprop="name">Starstruck</div>,
#  <div class="text-truncate" itemprop="name">Ferrari Horses</div>,
#  <div class="text-truncate" itemprop="name">Save Your Tears (Remix)</div>,
#  <div class="text-truncate" itemprop="name">Believe Me</div>,
#  <div class="text-truncate" itemprop="name">BED</div>,
#  <div class="text-truncate" itemprop="name">Head &amp; Heart (feat. MNEK)</div>,
#  <div class="text-truncate" itemprop="name">Didn't Know</div>,
#  <div class="text-truncate" itemprop="name">Goosebumps (Remix)</div>,
#  <div class="text-truncate" itemprop="name">Patience (feat. YUNGBLUD &amp; Polo G)</div>,
#  <div class="text-truncate" itemprop="name">Dancing in the Moonlight (feat. NEIMY)</div>,
#  <div class="text-truncate" itemprop="name">Get Out My Head</div>,
#  <div class="text-truncate" itemprop="name">Leave The Door Open</div>,
#  <div class="text-truncate" itemprop="name">My Head &amp; My Heart</div>,
#  <div class="text-truncate" itemprop="name">Don't Play</div>,
#  <div class="text-truncate" itemprop="name">Midnight Sky</div>,
#  <div class="text-truncate" itemprop="name">Blinding Lights</div>,
#  <div class="text-truncate" itemprop="name">HEAT</div>,
#  <div class="text-truncate" itemprop="name">Latest Trends</div>,
#  <div class="text-truncate" itemprop="name">We're Good</div>,
#  <div class="text-truncate" itemprop="name">Commitment Issues</div>,
#  <div class="text-truncate" itemprop="name">Your Love (9PM)</div>,
#  <div class="text-truncate" itemprop="name">Calling My Phone</div>,
#  <div class="text-truncate" itemprop="name">deja vu</div>,
#  <div class="text-truncate" itemprop="name">Don't You Worry About Me</div>,
#  <div class="text-truncate" itemprop="name">drivers license</div>,
#  <div class="text-truncate" itemprop="name">Diamonds</div>,
#  <div class="text-truncate" itemprop="name">Wellerman</div>,
#  <div class="text-truncate" itemprop="name">Rasputin</div>,
#  <div class="text-truncate" itemprop="name">Summer 91 (Looking Back)</div>,
#  <div class="text-truncate" itemprop="name">Last Time</div>,
#  <div class="text-truncate" itemprop="name">Break Up Song</div>,
#  <div class="text-truncate" itemprop="name">Good Without</div>,
#  <div class="text-truncate" itemprop="name">One Too Many</div>,
#  <div class="text-truncate" itemprop="name">Astronaut In The Ocean</div>,
#  <div class="text-truncate" itemprop="name">Up</div>,
#  <div class="text-truncate" itemprop="name">Medicine</div>,
#  <div class="text-truncate" itemprop="name">Runaway</div>,
#  <div class="text-truncate" itemprop="name">Nice To Meet Ya</div>,
#  <div class="text-truncate" itemprop="name">Wouldn't It Be Nice</div>,
#  <div class="text-truncate" itemprop="name">Little More Love</div>,
#  <div class="text-truncate" itemprop="name">Tonight (feat. D-Block Europe &amp; OBOY)</div>,
#  <div class="text-truncate" itemprop="name">Hold On</div>,
#  <div class="text-truncate" itemprop="name">Titanium</div>,
#  <div class="text-truncate" itemprop="name">SORRY NOT SORRY (feat. Nas, JAY-Z &amp; James Fauntleroy) [Harmonies by The Hive]</div>,
#  <div class="text-truncate" itemprop="name">Way Too Long</div>,
#  <div class="text-truncate" itemprop="name">All You Ever Wanted</div>,
#  <div class="text-truncate" itemprop="name">Another Love</div>,
#  <div class="text-truncate" itemprop="name">Take You Dancing</div>,
#  <div class="text-truncate" itemprop="name">BED (Joel Corry VIP Mix)</div>,
#  <div class="text-truncate" itemprop="name">The Four Horsemen</div>,
#  <div class="text-truncate" itemprop="name">Marea (We’ve Lost Dancing)</div>,
#  <div class="text-truncate" itemprop="name">Get It Poppin'</div>,
#  <div class="text-truncate" itemprop="name">Astronaut in the Ocean</div>,
#  <div class="text-truncate" itemprop="name">Levitating</div>,
#  <div class="text-truncate" itemprop="name">WITHOUT YOU</div>,
#  <div class="text-truncate" itemprop="name">Heat Waves</div>,
#  <div class="text-truncate" itemprop="name">Pas de prise de tête</div>,
#  <div class="text-truncate" itemprop="name">Shift the Culture (feat. Derek Minor, Eli Lefty &amp; The New Cool)</div>,
#  <div class="text-truncate" itemprop="name">Playing Games</div>,
#  <div class="text-truncate" itemprop="name">Loading</div>,
#  <div class="text-truncate" itemprop="name">Powiedz</div>,
#  <div class="text-truncate" itemprop="name">Arcade (feat. FLETCHER)</div>,
#  <div class="text-truncate" itemprop="name">Fly Freestyle (Instrumental)</div>,
#  <div class="text-truncate" itemprop="name">Track 15</div>,
#  <div class="text-truncate" itemprop="name">Eastender</div>,
#  <div class="text-truncate" itemprop="name">Deus É por Nós</div>,
#  <div class="text-truncate" itemprop="name">Paradise (feat. Dermot Kennedy)</div>,
#  <div class="text-truncate" itemprop="name">Rain On Me</div>,
#  <div class="text-truncate" itemprop="name">Simpin' Is As Simpin' Does</div>,
#  <div class="text-truncate" itemprop="name">Call Your Name (Extended Version)</div>,
#  <div class="text-truncate" itemprop="name">What’s Next</div>,
#  <div class="text-truncate" itemprop="name">Sweet Melody</div>,
#  <div class="text-truncate" itemprop="name">Kipó Mambo</div>,
#  <div class="text-truncate" itemprop="name">Lightning Crashes (Live)</div>,
#  <div class="text-truncate" itemprop="name">The Winner Takes It All</div>,
#  <div class="text-truncate" itemprop="name">Essence</div>,
#  <div class="text-truncate" itemprop="name">Stop Crying Your Heart Out (BBC Radio 2 Allstars)</div>,
#  <div class="text-truncate" itemprop="name">Blinded By the Lights</div>,
#  <div class="text-truncate" itemprop="name">Black Magic</div>,
#  <div class="text-truncate" itemprop="name">Circle The Endz</div>,
#  <div class="text-truncate" itemprop="name">Adore You</div>,
#  <div class="text-truncate" itemprop="name">Beautiful Mistakes</div>,
#  <div class="text-truncate" itemprop="name">Gangsta's Paradise (feat. L.V.)</div>,
#  <div class="text-truncate" itemprop="name">Blinding Lights (Instrumental)</div>,
#  <div class="text-truncate" itemprop="name">6 For 6</div>,
#  <div class="text-truncate" itemprop="name">Head &amp; Heart (Originally Performed by Joel Corry x MNEK) [Karaoke No Guide Melody Version]</div>]

# %%
soup.select("div.text-truncate")[1].get_text()
# Out:
# 'Tion Wayne, \xa0 Russ Millions'

# %%
title = []
artist = []
num_iter = len(soup.select("div.text-truncate"))

for i in range(num_iter):
    if i% 2 == 0:
        title.append(soup.select("div.text-truncate")[i].get_text())
    else:
        artist.append(soup.select("div.text-truncate")[i].get_text())

# %%
topuk= pd.DataFrame({"title":title,"artist":artist})

# %%
topuk = topuk.drop(labels=100, axis=0)

# %%
hits= pd.concat([topspain,topuk], axis=0)

# %%
hits
# Out:
#                                                 title  \
# 0                                      Pareja Del Año
# 1                                                Fiel
# 2                                  Flamenco y Bachata
# 3                                                  AM
# 4                                             Búmeran
# ..                                                ...
# 95                                 Beautiful Mistakes
# 96                    Gangsta's Paradise (feat. L.V.)
# 97                     Blinding Lights (Instrumental)
# 98                                            6 For 6
# 99  Head & Heart (Originally Performed by Joel Cor...
#
#                                    artist
# 0          Myke Towers,   Sebastián Yatra
# 1   Jhay Cortez,  Los Legendarios,  Wisin
# 2                      Daviles de Novelda
# 3              Flow La Movie,  Nio García
# 4                                  Beluga
# ..                                    ...
# 95         Megan Thee Stallion,  Maroon 5
# 96                                 Coolio
# 97                             The Weeknd
# 98                            Central Cee
# 99                                 EdKara
#
# [200 rows x 2 columns]

# %%
hits['title'] = hits['title'].str.replace("(",'').str.replace(')','')
# Out:
# C:\Users\gonza\AppData\Local\Temp/ipykernel_2424/651796404.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   hits['title'] = hits['title'].str.replace("(",'').str.replace(')','')

# %%
hits[['title', 'featuring']] = hits['title'].str.split('feat.', expand=True, n=1)

# %%
hits['featuring'] = hits['featuring'].replace('None', 'No feat')

# %%
hits = hits.fillna('no feat')

# %%
for i in hits.columns:
    hits[i] = list(map(lambda x: x.lower(), hits[i]))

# %%
hits['title'] = hits['title'].str.strip()

# %%
import random 
song_artist = input("What song or artist do you like?: ").lower()


if song_artist in list(hits['title']):
    print(random.choice(list(hits['title'])))
elif song_artist in list(hits['artist']):
    print(random.choice(list(hits['artist'])))
else:
    print('We cannot give you a recomendation yet')
# Out:
# What song or artist do you like?: myke
# We cannot give you a recomendation yet

# %%
# Out:
#                                                 title  \
# 0                                      pareja del año
# 1                                                fiel
# 2                                  flamenco y bachata
# 3                                                  am
# 4                                             búmeran
# ..                                                ...
# 95                                 beautiful mistakes
# 96                                 gangsta's paradise
# 97                       blinding lights instrumental
# 98                                            6 for 6
# 99  head & heart originally performed by joel corr...
#
#                                    artist featuring
# 0          myke towers,   sebastián yatra   no feat
# 1   jhay cortez,  los legendarios,  wisin   no feat
# 2                      daviles de novelda   no feat
# 3              flow la movie,  nio garcía   no feat
# 4                                  beluga   no feat
# ..                                    ...       ...
# 95         megan thee stallion,  maroon 5   no feat
# 96                                 coolio      l.v.
# 97                             the weeknd   no feat
# 98                            central cee   no feat
# 99                                 edkara   no feat
#
# [200 rows x 3 columns]
